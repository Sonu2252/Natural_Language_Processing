# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonu2252/Abhi/blob/master/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-de75b42a-405a-40f4-abbb-3d5422ab687a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de75b42a-405a-40f4-abbb-3d5422ab687a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv

# %%
import io
df1 = pd.read_csv(io.BytesIO(upload['train.csv']))
df1.head()
# Out:
#       Id                                              Tweet  following  \
# 0  10091  It's the everything else that's complicated. #...        0.0
# 1  10172  Eren sent a glare towards Mikasa then nodded a...        0.0
# 2   7012  I posted a new photo to Facebook http://fb.me/...        0.0
# 3   3697  #jan Idiot Chelsea Handler Diagnoses Trump Wit...     3319.0
# 4  10740  Pedophile Anthony Weiner is TERRIFIED of Getti...     4840.0
#
#    followers  actions  is_retweet       location     Type
# 0    11500.0      NaN         0.0        Chicago  Quality
# 1        0.0      NaN         0.0            NaN  Quality
# 2        0.0      NaN         0.0  Scotland, U.K  Quality
# 3      611.0    294.0         0.0    Atlanta, Ga     Spam
# 4     1724.0   1522.0         0.0       Blumberg     Spam

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Here it is found that both spam and quality tweet are same in number in the train dataset.
sns.countplot('Type', data = df1)
plt.title('Quality or Spam tweets.')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Quality or Spam tweets.')

# %%
df1['Type'].value_counts()
# Out:
# Quality    6153
# Spam       5815
# Name: Type, dtype: int64

# %%
#As we could see 'Type' data has to be predicted.
X_tr = df1.drop('Type', axis=1)   #Dropping the type column and storing only other columns
y_tr = df1['Type']

# %%
X_tr.head()
# Out:
#       Id                                              Tweet  following  \
# 0  10091  It's the everything else that's complicated. #...        0.0
# 1  10172  Eren sent a glare towards Mikasa then nodded a...        0.0
# 2   7012  I posted a new photo to Facebook http://fb.me/...        0.0
# 3   3697  #jan Idiot Chelsea Handler Diagnoses Trump Wit...     3319.0
# 4  10740  Pedophile Anthony Weiner is TERRIFIED of Getti...     4840.0
#
#    followers  actions  is_retweet       location
# 0    11500.0      NaN         0.0        Chicago
# 1        0.0      NaN         0.0            NaN
# 2        0.0      NaN         0.0  Scotland, U.K
# 3      611.0    294.0         0.0    Atlanta, Ga
# 4     1724.0   1522.0         0.0       Blumberg

# %%
#Values 0 for quality and 1 for spam mails
labelencoder = LabelEncoder()
y_tr = labelencoder.fit_transform(y_tr)
y_tr
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
X_tr.reset_index(inplace=True)
X_tr
# Out:
#        index     Id                                              Tweet  \
# 0          0  10091  It's the everything else that's complicated. #...
# 1          1  10172  Eren sent a glare towards Mikasa then nodded a...
# 2          2   7012  I posted a new photo to Facebook http://fb.me/...
# 3          3   3697  #jan Idiot Chelsea Handler Diagnoses Trump Wit...
# 4          4  10740  Pedophile Anthony Weiner is TERRIFIED of Getti...
# ...      ...    ...                                                ...
# 11963  11963   7866                                   11:11 meet harry
# 11964  11964   7841  If BBC Food disappears the loss of knowledge w...
# 11965  11965   9090  Look What Liberals Did to This Historic Monume...
# 11966  11966   6818  I uploaded a new track, "Everyday Lite 1", on ...
# 11967  11967   4937  Trump should be declared the victor by about 9...
#
#        following  followers  actions  is_retweet       location
# 0            0.0    11500.0      NaN         0.0        Chicago
# 1            0.0        0.0      NaN         0.0            NaN
# 2            0.0        0.0      NaN         0.0  Scotland, U.K
# 3         3319.0      611.0    294.0         0.0    Atlanta, Ga
# 4         4840.0     1724.0   1522.0         0.0       Blumberg
# ...          ...        ...      ...         ...            ...
# 11963        0.0        0.0      0.0         0.0            NaN
# 11964        0.0        0.0      NaN         0.0     London, N4
# 11965        0.0        2.0   1192.0         0.0  honeymoon ãve
# 11966        0.0        0.0      0.0         0.0    Mega Manila
# 11967     2028.0     1674.0   2729.0         1.0  United States
#
# [11968 rows x 8 columns]

# %%
X_tr.shape
# Out:
# (11968, 8)

# %%
upload1 = files.upload()
# Out:
#      <input type="file" id="files-68688162-5269-40c1-8fc9-ef2d9f5bb4e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68688162-5269-40c1-8fc9-ef2d9f5bb4e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv

# %%
#Upload the test file, where we have to predict whether the tweet is spam or quality
df2 = pd.read_csv(io.BytesIO(upload1['test.csv']))

# %%
df2.shape
# Out:
# (630, 7)

# %%
X_test = df2.copy()

# %%
X_test.shape
# Out:
# (630, 7)

# %%
X_test.reset_index(inplace=True)

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
abc = []
for i in range(0, len(X_tr)):
    tr = re.sub('[^a-zA-Z]', ' ', X_tr['Tweet'][i]) #Omit everything except for a-z and A-Z in 'tweet' column, with a blank.
    tr = tr.lower()       #Returns the lower case 
    tr = tr.split()       #To create list of words for stemming and stopwords
    
    tr = [ps.stem(word) for word in tr if not word in stopwords.words('english')]   #Returns the stemwords for most of the word and omit the stopwords from the english language
    tr = ' '.join(tr)    # Combining all the spaces with join function    
    abc.append(tr)      #every sentence is stored in abc

# %%
import tensorflow as tf
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import LSTM, Dense, Dropout, Flatten

# %%
#we have to represent each word with unique number so we use one hot encoding to represent each with the number between 0-10000.
voc_size = 10000
onehot_rep = [one_hot(words, voc_size) for words in abc]
onehot_rep
# Out:
# [[1847, 1860, 2345, 4830, 7326, 5078, 963, 1174, 4641],
#  [2115,
#   8120,
#   2133,
#   1647,
#   3825,
#   5083,
#   1290,
#   6128,
#   8674,
#   8250,
#   4495,
#   4474,
#   5034,
#   7908],
#  [4110, 5942, 7315, 4160, 6645, 330, 3323],
#  [7667,
#   7622,
#   6095,
#   4289,
#   5073,
#   4159,
#   631,
#   6645,
#   9140,
#   3198,
#   2496,
#   6645,
#   9140,
#   3006,
#   4811],
#  [6786, 2049, 5586, 3726, 2093, 9227, 2739, 6645, 9140, 2064, 59, 8505, 7162],
#  [9746, 1564, 4381, 2320, 8947, 5346, 6645, 9140, 7778],
#  [5412,
#   2550,
#   6916,
#   3206,
#   8696,
#   5176,
#   1487,
#   1666,
#   6645,
#   6883,
#   2340,
#   963,
#   8283,
#   7539,
#   9334],
#  [4898,
#   3532,
#   5711,
#   2076,
#   4704,
#   6505,
#   7287,
#   8053,
#   63,
#   8053,
#   3813,
#   1730,
#   3518,
#   9653,
#   613,
#   5078,
#   963,
#   4416,
#   5940],
#  [7939,
#   7110,
#   5984,
#   28,
#   6086,
#   7939,
#   2423,
#   6864,
#   9048,
#   7403,
#   6493,
#   6645,
#   542,
#   963,
#   5123,
#   7939,
#   5984,
#   28,
#   15,
#   8983,
#   5381,
#   5078,
#   963,
#   1339,
#   1334,
#   2220],
#  [2361,
#   2744,
#   2230,
#   538,
#   3170,
#   3991,
#   2349,
#   8587,
#   6645,
#   9140,
#   4051,
#   6645,
#   9140,
#   3130],
#  [2541, 5638, 9177, 5078, 963, 366],
#  [8935,
#   6753,
#   5993,
#   3896,
#   8870,
#   1402,
#   8181,
#   4375,
#   5381,
#   5078,
#   963,
#   2423,
#   7812,
#   7112],
#  [1921,
#   1132,
#   8999,
#   5785,
#   2828,
#   9807,
#   5733,
#   1006,
#   6645,
#   9140,
#   3868,
#   1443,
#   1852,
#   6645,
#   9140,
#   6940,
#   7017,
#   4677],
#  [8278,
#   4159,
#   9687,
#   2111,
#   5443,
#   3341,
#   3054,
#   9233,
#   3627,
#   5318,
#   6645,
#   9140,
#   4063,
#   436,
#   6645,
#   9140,
#   9145],
#  [5161, 6645, 9140, 103],
#  [7934,
#   819,
#   7934,
#   819,
#   8557,
#   8077,
#   7432,
#   473,
#   1631,
#   6645,
#   6883,
#   2340,
#   963,
#   8283,
#   7551,
#   578],
#  [3488, 6682, 7266, 2187, 5831, 8408, 3247, 2843, 3138, 8895, 6879],
#  [9396, 34, 6645, 5078, 963, 2486, 6676, 5105],
#  [5668, 814, 7205, 9948, 1811, 5956, 5116, 6358],
#  [2303,
#   2010,
#   9350,
#   1309,
#   2989,
#   4706,
#   8818,
#   5352,
#   1309,
#   2989,
#   4706,
#   157,
#   73,
#   5936,
#   73,
#   3496,
#   1918],
#  [8890, 2220, 1987, 6645, 1686, 8099, 2630, 6645, 5078, 963, 895, 6676],
#  [9730, 7000, 6645, 9140, 448, 6645, 9140, 3393, 5443],
#  [1078, 6645, 330, 111],
#  [5805, 9945, 6031, 6645, 330, 8409],
#  [706,
#   6128,
#   3347,
#   1119,
#   6142,
#   3359,
#   1493,
#   6128,
#   9615,
#   2064,
#   5020,
#   6883,
#   2347,
#   9140,
#   2141,
#   5620,
#   2141,
#   5620,
#   5052,
#   3574,
#   3499,
#   759],
#  [9225, 1119, 8013, 2233],
#  [3149, 9791, 7719, 2505, 7567, 6857, 1876],
#  [9512,
#   8108,
#   8744,
#   9392,
#   4018,
#   5234,
#   8108,
#   5373,
#   9064,
#   8559,
#   4661,
#   8559,
#   474,
#   8902],
#  [9408, 1257, 178, 9630, 6864, 9227, 2283, 8843, 9005, 5620],
#  [9152, 2494, 1349, 9241, 8341, 2349, 8409, 6645, 9140, 7633],
#  [4970, 1679],
#  [4499,
#   6995,
#   1977,
#   5241,
#   9350,
#   3244,
#   1498,
#   1048,
#   584,
#   8278,
#   6645,
#   9140,
#   4471,
#   2064],
#  [6386, 1023, 7137, 6818, 642, 8310, 8573, 6116, 1640, 8874, 9970, 2225, 2797],
#  [4882, 5078, 963, 1194, 7320],
#  [7567, 6868, 2612, 5433],
#  [4705,
#   6524,
#   7669,
#   6356,
#   759,
#   4396,
#   9493,
#   8910,
#   3099,
#   711,
#   3431,
#   8483,
#   6645,
#   5485,
#   5625,
#   386],
#  [9168,
#   759,
#   4391,
#   2324,
#   2460,
#   6080,
#   3873,
#   2989,
#   1546,
#   7750,
#   5381,
#   5078,
#   963,
#   3544,
#   6277],
#  [9421, 6734, 5510],
#  [7000],
#  [3469, 3847, 5989, 3728, 8368, 6645, 3149, 2491, 6419],
#  [4707, 607, 9217],
#  [447, 1326, 7036, 4159, 3891, 5400, 1575, 7506, 6645, 9140, 7901, 1177, 9959],
#  [5610, 6101, 4881, 63, 4686, 4881, 1845, 8701, 8634, 6603, 829, 8936],
#  [6871, 6665, 231, 230, 6991, 2519, 2364, 7238, 8021],
#  [774, 5942, 907, 7793, 1870, 3873, 68, 1515, 5381, 5078, 963, 8726, 7712],
#  [5433, 4286, 5936, 3298, 7436, 9200, 8185, 3102, 642, 1845],
#  [8540,
#   1980,
#   9447,
#   2818,
#   321,
#   3162,
#   1088,
#   9233,
#   4465,
#   2624,
#   6645,
#   9140,
#   5662,
#   6645,
#   9140,
#   9120,
#   1740],
#  [8195, 9652, 9935, 2359, 795, 5321, 3211],
#  [8936, 9115, 906, 512, 4027, 6645, 9140, 267, 9539, 4063],
#  [4159,
#   7757,
#   5942,
#   2992,
#   104,
#   6645,
#   9140,
#   1941,
#   6645,
#   9140,
#   5940,
#   3648,
#   9753,
#   4237],
#  [3132, 4490, 7357, 4010, 9532, 8132, 6645, 9140, 2268, 9116],
#  [3126, 7149, 2027, 2483, 5105, 6645, 9140, 4231, 482, 5620],
#  [3734, 6685, 9915, 1564, 7757, 9182, 9070, 5262, 5620],
#  [5615, 7890],
#  [6176, 6645, 5078, 963, 8026, 5020, 1536, 6676],
#  [8478,
#   1905,
#   5432,
#   2695,
#   6645,
#   9140,
#   6289,
#   6948,
#   8164,
#   6645,
#   9140,
#   1059,
#   1986],
#  [4376, 1071, 3539, 4602],
#  [9791, 3445, 1857, 561],
#  [1846,
#   3064,
#   904,
#   5034,
#   4159,
#   9056,
#   6645,
#   9140,
#   5211,
#   8377,
#   7759,
#   6645,
#   9140,
#   6493,
#   8479,
#   3598],
#  [9643, 1352, 6594, 8225, 1346, 8737],
#  [3041, 3381, 4110, 3499, 642, 8954, 5078, 963, 1131, 9050],
#  [6645,
#   6883,
#   7521,
#   9140,
#   2141,
#   5620,
#   680,
#   3726,
#   4211,
#   6398,
#   6732,
#   5436,
#   7078,
#   7924,
#   5669,
#   4555,
#   4610,
#   8597,
#   6129,
#   8003,
#   7574,
#   4030,
#   4555],
#  [445,
#   2027,
#   2238,
#   3076,
#   4384,
#   7412,
#   7931,
#   1368,
#   104,
#   6645,
#   6883,
#   1438,
#   3103,
#   3076,
#   2027,
#   7412,
#   7931,
#   1368,
#   5381,
#   5078,
#   963,
#   393,
#   8500,
#   7685],
#  [2093, 4836, 4221, 997, 5392, 7403, 9385, 1309, 6665, 5078, 1010, 8989, 9410],
#  [3510, 4939, 4211, 6047, 1156, 2866, 716, 5034],
#  [2364,
#   7212,
#   5669,
#   1237,
#   5004,
#   9518,
#   4922,
#   7792,
#   2663,
#   1271,
#   8230,
#   6645,
#   8582,
#   8159,
#   6669,
#   3363],
#  [6659],
#  [2935,
#   8870,
#   9350,
#   8120,
#   5129,
#   8772,
#   6749,
#   3060,
#   3734,
#   7332,
#   2797,
#   6645,
#   9140,
#   6859,
#   8465],
#  [2137, 4142, 7943, 8132, 9720, 6010, 3633, 6645, 9140, 8182, 2174],
#  [1679, 8576, 9851, 3162, 3492, 4148, 6645, 9140, 6718, 1691, 9435],
#  [9575, 24, 9858, 8901, 6645, 5078, 963, 7225, 6676],
#  [5038,
#   2015,
#   2930,
#   989,
#   4264,
#   4333,
#   8445,
#   473,
#   3748,
#   1147,
#   759,
#   1730,
#   2285,
#   6645,
#   9140,
#   5117,
#   3967,
#   5620],
#  [7261,
#   258,
#   3374,
#   8947,
#   3715,
#   1846,
#   8331,
#   3075,
#   6645,
#   9140,
#   993,
#   5731,
#   6645,
#   9140,
#   5940,
#   300],
#  [7284, 7284, 5110, 7501, 1475, 6645, 9140, 8921, 7381],
#  [8211, 3666, 332, 8199, 3628, 1029, 3068, 9116, 6645, 2845, 8159, 8972, 6940],
#  [6545,
#   4211,
#   5764,
#   4516,
#   3939,
#   4912,
#   6645,
#   3912,
#   2895,
#   963,
#   4063,
#   8413,
#   5731,
#   6289,
#   5940,
#   1132,
#   2622,
#   8687,
#   6289,
#   7458],
#  [6001, 9376, 2012, 5477, 4590, 6645, 9140, 3235, 6645, 9140, 348],
#  [5474,
#   477,
#   1270,
#   7166,
#   3811,
#   6805,
#   4959,
#   7902,
#   6645,
#   9140,
#   3032,
#   6645,
#   9140,
#   5331,
#   8283],
#  [4231,
#   6568,
#   769,
#   795,
#   601,
#   4374,
#   9799,
#   5323,
#   4912,
#   6645,
#   9140,
#   8660,
#   6645,
#   9140,
#   7693,
#   6693],
#  [4323, 6228, 8698, 1352, 8935, 5301, 9182, 1352, 1758, 104, 2818, 8566],
#  [1056,
#   6031,
#   271,
#   8408,
#   7013,
#   2550,
#   994,
#   6645,
#   9140,
#   708,
#   5509,
#   6645,
#   9140,
#   4128,
#   5189],
#  [5909,
#   508,
#   8709,
#   8737,
#   4899,
#   378,
#   3873,
#   9945,
#   6080,
#   6645,
#   5078,
#   963,
#   8134,
#   6676],
#  [9090, 8870, 6128, 108, 8478, 4993],
#  [9528,
#   4485,
#   7372,
#   2257,
#   1054,
#   9528,
#   4485,
#   6568,
#   2257,
#   3824,
#   6645,
#   2845,
#   8159,
#   842,
#   8875,
#   3591],
#  [2483,
#   3811,
#   6176,
#   2041,
#   3912,
#   1758,
#   6690,
#   5278,
#   9153,
#   8642,
#   7536,
#   2314,
#   3297,
#   7207,
#   5831,
#   3162,
#   6142,
#   5412,
#   774,
#   5369,
#   9170,
#   4643,
#   7338,
#   2422,
#   1546,
#   3162,
#   2111,
#   6645,
#   9140,
#   7994,
#   6645,
#   9140,
#   8283,
#   3254,
#   7911],
#  [2093, 5072, 2087, 24, 3639, 8679, 2262, 1116, 8186],
#  [68, 3459, 8897, 1789, 5030, 5301, 8433],
#  [7415, 3873, 1253, 1826, 8897, 1233, 4592, 8042, 6020, 1831, 842],
#  [4018,
#   5163,
#   6887,
#   3185,
#   7706,
#   5105,
#   6645,
#   9140,
#   7403,
#   759,
#   8036,
#   536,
#   498,
#   258],
#  [4026, 1837],
#  [5911,
#   4419,
#   5400,
#   5865,
#   2744,
#   1054,
#   7011,
#   4286,
#   9986,
#   6645,
#   9140,
#   5611,
#   6645,
#   9140,
#   6124,
#   4641],
#  [8195, 888, 1844, 5923, 2093, 5057],
#  [8847,
#   2454,
#   3111,
#   9793,
#   3000,
#   6645,
#   2845,
#   8159,
#   8203,
#   6261,
#   5381,
#   5078,
#   963,
#   8616,
#   8934,
#   9615,
#   3198],
#  [3279, 5738, 6455, 685, 6487, 5381, 5078, 963, 8934, 4144, 6207],
#  [9528,
#   796,
#   6551,
#   9413,
#   4596,
#   9048,
#   4994,
#   6645,
#   2845,
#   8159,
#   3215,
#   8936,
#   7124,
#   9873,
#   3137,
#   971,
#   6894,
#   309],
#  [5323,
#   6459,
#   3507,
#   3191,
#   9064,
#   5562,
#   1926,
#   8336,
#   6645,
#   9140,
#   7512,
#   1633,
#   7723,
#   6645,
#   9140,
#   8283,
#   8227,
#   1701],
#  [3489,
#   477,
#   6567,
#   9782,
#   8899,
#   9580,
#   9791,
#   5323,
#   8438,
#   4888,
#   6645,
#   8582,
#   8159,
#   9449,
#   3044],
#  [3179, 414, 6645, 1923, 5200, 2220, 3981],
#  [1054,
#   642,
#   2093,
#   9782,
#   3272,
#   759,
#   7432,
#   5387,
#   5251,
#   4881,
#   9344,
#   9890,
#   6645,
#   5078,
#   963,
#   7482,
#   6676],
#  [4175, 7053, 3265, 9041, 2655, 1797, 8048],
#  [6727,
#   3075,
#   459,
#   9718,
#   8223,
#   666,
#   1369,
#   6143,
#   7246,
#   4159,
#   6645,
#   9140,
#   7523,
#   3198,
#   4372,
#   8195],
#  [6920, 7622, 2710, 9350, 7791, 2718],
#  [3602,
#   8756,
#   8772,
#   843,
#   5443,
#   4654,
#   7884,
#   2482,
#   6645,
#   9140,
#   5728,
#   6645,
#   9140,
#   4715,
#   2943],
#  [4837, 2980, 7770, 1666, 4912, 5911, 6645, 9140, 5086, 6169],
#  [8395, 6645, 5078, 963, 7554, 6676],
#  [7447,
#   6480,
#   6238,
#   3331,
#   2004,
#   5265,
#   6010,
#   6372,
#   5139,
#   7172,
#   6480,
#   4619,
#   1837,
#   2262,
#   6645,
#   9140,
#   728,
#   4162,
#   9796],
#  [8464, 1257, 9064, 4991, 9718, 6645, 9140, 2496, 2033, 5620],
#  [5052, 4686, 888, 6558, 9227, 9201, 2720, 6588, 6645, 9140, 5205, 9838, 3798],
#  [5191, 3365, 7265, 6049, 4379, 4010, 1564],
#  [5668,
#   9832,
#   358,
#   7510,
#   2036,
#   2748,
#   8326,
#   7510,
#   9456,
#   4046,
#   9535,
#   7510,
#   9021,
#   5078,
#   963,
#   2023,
#   2423],
#  [9635,
#   4431,
#   83,
#   6573,
#   4018,
#   6562,
#   6562,
#   9089,
#   6645,
#   9140,
#   1534,
#   6645,
#   9140,
#   8367,
#   5088],
#  [3977,
#   8310,
#   1688,
#   7908,
#   6544,
#   593,
#   5321,
#   5321,
#   474,
#   8165,
#   3977,
#   5993,
#   9005,
#   6645,
#   1937,
#   873],
#  [1847, 4611, 2828, 9707, 3170, 8274, 6645, 3703, 963, 8283, 1780],
#  [9226,
#   8409,
#   7791,
#   6805,
#   9894,
#   1119,
#   5942,
#   7802,
#   1349,
#   750,
#   3193,
#   459,
#   4829,
#   2460,
#   3275,
#   7454,
#   7205,
#   7881],
#  [4013, 9586, 674, 9265, 6645, 9140, 6940, 7846, 6645, 9140, 825, 4401],
#  [6195, 5714, 8331, 536, 1235, 2230, 43, 6645, 9140, 3198, 2308, 546],
#  [1367, 2479, 9424, 5730, 8117, 6300, 5857, 6645, 330, 7665, 5211],
#  [3257,
#   5633,
#   8162,
#   3407,
#   2718,
#   1457,
#   1203,
#   3341,
#   370,
#   5422,
#   4899,
#   717,
#   8470,
#   6645,
#   9140,
#   2416,
#   6051],
#  [6343,
#   8934,
#   6207,
#   9518,
#   4893,
#   9418,
#   9418,
#   1879,
#   8120,
#   9916,
#   7067,
#   6645,
#   9140,
#   3428,
#   5357,
#   3967,
#   5620],
#  [1873, 5278, 5697, 6645, 9140, 3907, 4296],
#  [9791, 2364, 615, 3162, 1789, 3843, 1976],
#  [9624, 1054, 8277, 721],
#  [4300,
#   2095,
#   9953,
#   563,
#   9314,
#   3799,
#   8306,
#   1562,
#   6645,
#   9140,
#   671,
#   5040,
#   6645,
#   9140,
#   8095,
#   2964,
#   6940],
#  [2081, 1870, 5381, 5078, 963, 7524, 8527],
#  [5771, 6645, 5078, 963, 7170, 6676],
#  [5410,
#   9708,
#   8870,
#   2270,
#   1943,
#   1272,
#   6645,
#   9140,
#   4511,
#   319,
#   6645,
#   9140,
#   1407,
#   2256,
#   2486],
#  [9168, 3793, 5078, 963, 3494, 8268],
#  [8103, 7000, 3873, 3024],
#  [921,
#   7247,
#   4159,
#   5541,
#   9057,
#   5443,
#   4376,
#   9201,
#   3873,
#   9051,
#   6645,
#   9140,
#   3849,
#   367,
#   6645,
#   9140,
#   2277,
#   2811],
#  [1444,
#   7187,
#   9460,
#   2978,
#   4120,
#   5425,
#   5942,
#   1444,
#   7187,
#   6645,
#   9056,
#   287,
#   6764,
#   6851,
#   8668,
#   1444,
#   7187,
#   9460,
#   2978,
#   4120,
#   5425,
#   5942,
#   6645,
#   330,
#   9184,
#   8934,
#   4687],
#  [8531, 6645, 5078, 963, 2109, 6676],
#  [8224, 2364, 8250, 8274, 1286, 4899, 1483, 4970, 7111, 2734, 5078, 963, 4175],
#  [642, 1075, 814, 5226, 5195, 8936, 2980, 5341, 6645, 5078, 963, 6115, 6676],
#  [1408,
#   1846,
#   5443,
#   2667,
#   9020,
#   7701,
#   3734,
#   7332,
#   9022,
#   4165,
#   1961,
#   6645,
#   9140,
#   3844,
#   8827,
#   5088,
#   6645,
#   9140,
#   5216,
#   7642],
#  [9624, 3628, 5192, 5192, 2, 7121, 7498, 7162, 1969],
#  [1581, 4022, 9759, 9133, 6645, 9140, 6876, 1002, 3969],
#  [2010, 7487, 812, 8165, 6645, 812, 6919],
#  [8407,
#   3635,
#   5165,
#   1884,
#   3016,
#   4686,
#   6546,
#   942,
#   8464,
#   5257,
#   6645,
#   9140,
#   4416,
#   6382,
#   8934],
#  [6493, 6954, 841, 3714, 862, 9294, 6706, 8560, 1799, 7667],
#  [3783, 7881, 5942, 4650, 1054, 8874, 5443, 9165, 9505, 3793, 8687, 2132],
#  [5105,
#   7374,
#   5126,
#   4286,
#   7011,
#   9963,
#   1666,
#   6645,
#   9140,
#   1391,
#   6645,
#   9140,
#   4686,
#   8254,
#   4574],
#  [8903, 5078, 963, 4717, 7315],
#  [4159, 8037, 8209, 759, 7159, 5757, 2550, 6316, 1390, 3246, 3320],
#  [2722,
#   1084,
#   8076,
#   9392,
#   5021,
#   9750,
#   6754,
#   9640,
#   5071,
#   732,
#   6645,
#   6645,
#   4915,
#   3520,
#   5381,
#   5078,
#   963,
#   1145],
#  [7791,
#   8396,
#   317,
#   1317,
#   7022,
#   2483,
#   6818,
#   8345,
#   4596,
#   5381,
#   5078,
#   963,
#   1911,
#   5312],
#  [4177,
#   4837,
#   1203,
#   2739,
#   8673,
#   4969,
#   4110,
#   2009,
#   6541,
#   7738,
#   6645,
#   9140,
#   748,
#   9210,
#   6645,
#   9140,
#   1124],
#  [2089,
#   843,
#   1766,
#   815,
#   8280,
#   459,
#   608,
#   6645,
#   9140,
#   934,
#   6645,
#   9140,
#   2850,
#   2958,
#   8408],
#  [1925, 4123, 1174, 1963, 9706, 7772, 5620],
#  [3106,
#   2508,
#   5422,
#   3603,
#   3665,
#   6547,
#   6072,
#   2435,
#   7799,
#   5078,
#   963,
#   5102,
#   5088,
#   8804],
#  [2663, 1734, 5381, 5078, 963, 5246],
#  [3198],
#  [7555, 6659, 7711, 442, 4108, 586, 3279, 3075, 6645, 2845, 8159, 8718],
#  [2999,
#   1577,
#   989,
#   2655,
#   5353,
#   4043,
#   108,
#   5092,
#   3268,
#   5773,
#   2488,
#   3602,
#   9112,
#   7731,
#   958,
#   2093,
#   2903,
#   829,
#   2010,
#   6645,
#   9140,
#   1472,
#   7205,
#   7978],
#  [9095, 8870, 2119, 5422, 9200],
#  [3873, 4871, 804, 5343, 7719, 9350, 596, 8233, 3891, 3899, 6534, 1390],
#  [5356, 611, 5311, 3575, 6820, 4189, 8274, 4016, 5078, 963, 1975],
#  [6645, 9140, 1770, 8174],
#  [6493,
#   9338,
#   5908,
#   1054,
#   8395,
#   2093,
#   5862,
#   9233,
#   1253,
#   4377,
#   2432,
#   6645,
#   9140,
#   8310,
#   5861],
#  [3826,
#   3634,
#   2583,
#   43,
#   1075,
#   9634,
#   3298,
#   6645,
#   6418,
#   526,
#   2314,
#   5381,
#   5078,
#   963,
#   2055,
#   1288],
#  [3328, 3014, 4922, 108, 4611, 8551, 3016],
#  [9369,
#   4294,
#   1898,
#   4159,
#   7524,
#   3603,
#   7864,
#   5942,
#   3170,
#   2486,
#   1083,
#   1766,
#   6645,
#   9140,
#   8377,
#   3688],
#  [369, 664, 1845, 9899, 9718, 6645, 5078, 963, 1209, 6676],
#  [6493, 3639, 1590, 5936, 958, 6557, 4108, 7048, 4155],
#  [551, 6645, 5078, 963, 5500, 6676],
#  [6199, 8485, 2654, 3424, 6296, 1595, 3016],
#  [6080, 6974, 7432, 5936, 2361],
#  [6522, 3092, 4608],
#  [9350, 6577, 9932, 6961],
#  [7903, 5381, 5078, 963, 4027, 4889],
#  [8250,
#   7026,
#   2225,
#   8721,
#   5783,
#   8771,
#   7045,
#   6645,
#   2845,
#   8159,
#   287,
#   1381,
#   5381,
#   5078,
#   963,
#   3633,
#   593],
#  [8250, 3092],
#  [4357, 3935, 3519, 8431, 8134, 5138, 5381, 5078, 963, 4183, 5923],
#  [1846, 5105, 6300, 815, 4159, 9812, 6645, 9140, 6730, 1701, 5840],
#  [7560, 4813, 7763, 4126, 3283],
#  [9599,
#   2921,
#   8679,
#   1151,
#   774,
#   1327,
#   1789,
#   5244,
#   7567,
#   9797,
#   1646,
#   2550,
#   9954,
#   5078,
#   963,
#   2234,
#   699],
#  [1846,
#   9392,
#   9948,
#   3783,
#   7957,
#   7513,
#   9449,
#   1486,
#   6676,
#   6645,
#   9140,
#   8866,
#   6645,
#   9140,
#   3494,
#   1275],
#  [7100, 6142, 9797, 9851, 9791, 5049, 5078, 963, 461, 6527, 2423],
#  [6509, 1994, 1698, 4190, 3308, 1203, 290, 869, 3575, 8195],
#  [6639, 3864, 8224, 5668],
#  [3279, 7674, 4658, 3431, 3343, 1402, 5892, 4376, 721],
#  [1054, 1327, 1221, 1116, 6411, 3819, 8800, 4235, 108, 612, 2550],
#  [9493, 6836, 8571, 6753, 2980, 3104, 6645, 2845, 8159, 7769, 8875, 9724],
#  [4411, 9064, 8408, 1646, 3963, 5942, 6635, 1321],
#  [7332, 4775, 1081, 2744, 6128, 6901, 8358, 9851],
#  [7205, 5851, 5538, 1054, 7831, 2532, 1023, 2903],
#  [3281, 6685, 8999, 5669, 6645, 9140, 7315, 206, 6645, 9140, 1565, 7712],
#  [9508, 5034, 5078, 963, 7764, 6676],
#  [2,
#   142,
#   5038,
#   2878,
#   6370,
#   4414,
#   6645,
#   6883,
#   142,
#   6754,
#   680,
#   1354,
#   2798,
#   2878,
#   6370,
#   4414,
#   5381,
#   5078,
#   963,
#   7050,
#   8344,
#   6343],
#  [1286,
#   7501,
#   3573,
#   4899,
#   9634,
#   6459,
#   4135,
#   4556,
#   8787,
#   5278,
#   1016,
#   4436,
#   6645,
#   6459,
#   2423,
#   75,
#   963,
#   5620,
#   6459,
#   5278,
#   162,
#   1016,
#   8177,
#   4436],
#  [5668, 8408, 290, 2550, 8980, 920, 5381, 5078, 963, 4372, 8045, 9184],
#  [5101, 4863, 8674, 1116, 6316, 4759, 7067, 6887, 5620],
#  [5128,
#   3846,
#   1884,
#   4590,
#   6142,
#   1873,
#   841,
#   6049,
#   3060,
#   492,
#   6645,
#   9140,
#   8525,
#   8505],
#  [8994, 831, 3687, 6645, 812, 624, 1853, 1603, 9566, 5078, 963, 8062],
#  [8179, 9227, 411, 2093, 7501, 6645, 9140, 4843, 5445, 8875, 3140],
#  [2070, 2663, 2089, 2550, 2602, 6031, 352, 5078, 963, 4499, 5857, 2064],
#  [4414,
#   7966,
#   9952,
#   8685,
#   9699,
#   1961,
#   2818,
#   7106,
#   3802,
#   5511,
#   9355,
#   6645,
#   2845,
#   8159,
#   1594,
#   9911,
#   8875,
#   3802],
#  [8936,
#   8720,
#   2368,
#   1884,
#   6474,
#   266,
#   207,
#   8997,
#   6645,
#   4768,
#   6754,
#   3240,
#   6674,
#   4768,
#   1852],
#  [3700,
#   7166,
#   7237,
#   4717,
#   625,
#   4186,
#   7633,
#   5458,
#   9387,
#   2709,
#   5078,
#   963,
#   9090,
#   2981,
#   1923],
#  [4251, 6732, 5170, 5902, 1921, 5902, 642, 7159, 8037, 2930, 529],
#  [8587, 1663, 2744, 5195, 348, 1326, 1995, 6991, 657, 3016],
#  [1209, 8674, 7708, 8679, 1209, 642, 6645, 9140, 3622],
#  [6189, 5078, 963, 7709, 6676],
#  [5367,
#   2744,
#   666,
#   3050,
#   3419,
#   8921,
#   7315,
#   958,
#   6560,
#   5367,
#   2744,
#   666,
#   3050,
#   3126,
#   9899],
#  [7383,
#   2,
#   4108,
#   9419,
#   4631,
#   3298,
#   2052,
#   9357,
#   6645,
#   9140,
#   8037,
#   6879,
#   9233,
#   4159,
#   2296,
#   4203],
#  [3279, 7864, 1646, 932, 679, 1147, 2550, 6465, 793, 2822, 3279],
#  [642, 303, 8806, 8165, 5400, 5379, 8117, 7172, 7575, 2244, 5620],
#  [2009, 5738, 7461, 8222, 5350, 3427, 3186, 6645, 8582, 8159, 5679, 7069],
#  [8177,
#   6493,
#   2317,
#   7205,
#   8243,
#   4375,
#   6573,
#   894,
#   2744,
#   8904,
#   398,
#   7022,
#   759,
#   3811,
#   8934,
#   6645,
#   9140,
#   156,
#   3153],
#  [5061, 1666, 8157, 9410, 6128, 3981, 2663],
#  [7998,
#   5068,
#   2406,
#   1758,
#   8088,
#   7284,
#   4159,
#   6645,
#   9140,
#   2277,
#   6645,
#   9140,
#   5179],
#  [8224, 2157, 4233],
#  [2304,
#   2970,
#   2370,
#   9447,
#   4638,
#   1023,
#   8786,
#   6758,
#   4912,
#   2049,
#   1553,
#   6702,
#   6645,
#   5782,
#   5324],
#  [759, 7159, 5234, 9282, 3179, 6953, 6645, 9140, 2020, 6645, 9140, 3198, 7861],
#  [2855,
#   1121,
#   6493,
#   963,
#   841,
#   6795,
#   2980,
#   6876,
#   1085,
#   9899,
#   9350,
#   6741,
#   642,
#   841],
#  [1054,
#   7338,
#   2167,
#   3406,
#   5373,
#   1367,
#   7454,
#   6645,
#   9140,
#   3166,
#   8990,
#   6645,
#   9140,
#   6436],
#  [7018, 471, 7137, 6645, 9140, 8967, 178],
#  [1501,
#   5865,
#   18,
#   5942,
#   1182,
#   5942,
#   4555,
#   2415,
#   1132,
#   7203,
#   6645,
#   9140,
#   1006,
#   6343,
#   8716],
#  [1208, 7077, 7205, 7400, 6465, 1845, 1390, 9945, 492, 4283, 1906],
#  [4115, 6207, 4517, 4775, 6645, 1686, 8415, 5051, 8875, 2710],
#  [4159, 2093, 3719, 9767, 4286, 6142, 6645, 9140, 2220, 3198, 7145],
#  [9313, 3075, 3050, 3859, 43, 3913, 3398, 3050, 2451],
#  [1758, 1147, 5321, 2818, 1081, 4922, 9200, 1147, 1147, 446],
#  [8870, 6262, 1515, 6977, 229, 7077, 2010],
#  [7792, 4375, 3864, 9449, 7444],
#  [4954, 6142, 2093, 4718, 5562, 9232, 7432],
#  [1147, 8870, 2111, 9851, 3298, 632, 7750, 1826, 5668, 3830, 7164, 3186, 6617],
#  [8197, 7881, 9217, 4286, 6645, 6883, 4286, 963, 8283, 8680, 3161],
#  [7348,
#   5099,
#   8737,
#   9841,
#   1627,
#   3633,
#   7260,
#   6645,
#   4285,
#   963,
#   7348,
#   5099,
#   8737,
#   9841,
#   1627,
#   3633,
#   7260,
#   5381,
#   5078,
#   963,
#   7546,
#   3746],
#  [6493,
#   3849,
#   3398,
#   1758,
#   7284,
#   2262,
#   6096,
#   7792,
#   769,
#   7757,
#   7881,
#   1701,
#   6645,
#   9140,
#   6226],
#  [498, 4775, 8753, 5066, 2748, 7260, 2658, 6805, 6645, 9140, 2674, 6510, 9197],
#  [7395,
#   9227,
#   7072,
#   6300,
#   2717,
#   108,
#   6645,
#   9140,
#   9335,
#   7661,
#   6645,
#   9140,
#   6308,
#   4619],
#  [3006, 7171, 5443, 1352, 6603, 278, 4852, 2423, 5008, 4719, 5126, 1066, 9919],
#  [565, 7839, 8573, 3489, 1160, 5524, 9437, 6645, 5078, 963, 6963, 6676],
#  [6280, 5942, 4836, 8737, 424, 5387, 4370, 1023, 6128, 8547, 639, 5923],
#  [3873, 8674, 4344, 6192, 5381, 5078, 963, 8283, 6144],
#  [861, 8197, 5680, 6171, 785, 6143, 1110, 2077, 6645, 1686, 8337, 2743],
#  [1332,
#   9315,
#   6645,
#   6883,
#   2340,
#   963,
#   8283,
#   8609,
#   1132,
#   6645,
#   9605,
#   6516,
#   963,
#   6289,
#   2423,
#   9752,
#   7360,
#   8281,
#   5568,
#   1771,
#   8232,
#   2107,
#   8553,
#   9752,
#   5940],
#  [9345, 7757, 8940, 1491, 3075, 5620],
#  [4656,
#   478,
#   9215,
#   3132,
#   5400,
#   6814,
#   2385,
#   4974,
#   6645,
#   9140,
#   4398,
#   6645,
#   9140,
#   9623,
#   1644,
#   5190],
#  [4136,
#   1786,
#   3595,
#   2244,
#   4117,
#   3930,
#   9597,
#   8501,
#   694,
#   6198,
#   9815,
#   5381,
#   5078,
#   963,
#   2491],
#  [1156, 9161, 4016, 2210, 5191, 8486, 6645, 5078, 963, 467, 6676],
#  [7541, 8527, 4667, 7518, 3495, 8021],
#  [2205, 6128, 6316, 6101, 1444],
#  [6808,
#   7276,
#   4112,
#   4159,
#   6432,
#   709,
#   2077,
#   6441,
#   8400,
#   6645,
#   9140,
#   8344,
#   1510,
#   8934,
#   1701,
#   6645,
#   9140,
#   6452],
#  [6330, 5178, 2111, 3651, 7605, 6645, 9140, 4278, 8195],
#  [7864, 8026, 5136, 5748, 5136, 2999, 5136, 5110, 5136, 5136],
#  [9392,
#   9948,
#   3783,
#   9140,
#   5702,
#   442,
#   1178,
#   1470,
#   6645,
#   9140,
#   7209,
#   7724,
#   7360,
#   1294,
#   6645,
#   9140,
#   4344,
#   9204],
#  [3683,
#   6940,
#   1132,
#   8981,
#   5731,
#   8672,
#   6379,
#   8379,
#   5601,
#   1388,
#   7862,
#   362,
#   5974,
#   1102,
#   6177,
#   8201,
#   4636,
#   2234,
#   8976,
#   5987,
#   8144,
#   2367,
#   4211,
#   5733,
#   7111,
#   4245,
#   1644,
#   7211,
#   9490,
#   5479,
#   8739,
#   1286,
#   106,
#   9172,
#   6820,
#   1861,
#   4878,
#   1861,
#   3462,
#   9963,
#   1873,
#   1839,
#   5404,
#   373,
#   1766],
#  [9225, 1846, 9587, 1557, 8250, 3278, 1845, 2052],
#  [862,
#   5135,
#   1328,
#   3406,
#   5170,
#   3297,
#   4829,
#   3162,
#   1088,
#   6645,
#   9140,
#   3357,
#   6645,
#   9140,
#   2271],
#  [6474,
#   9873,
#   8222,
#   421,
#   7756,
#   6164,
#   642,
#   2742,
#   759,
#   6645,
#   9140,
#   6010,
#   3331,
#   6645,
#   9140,
#   9287,
#   2064],
#  [1058,
#   328,
#   4205,
#   8283,
#   985,
#   3643,
#   1826,
#   6129,
#   9090,
#   7401,
#   8340,
#   1081,
#   6645,
#   6128,
#   7445,
#   4238],
#  [3452],
#  [3955, 173, 1431, 3462, 9122, 2089, 759, 1852, 6645, 9140, 9281, 6813],
#  [8899,
#   1405,
#   1543,
#   8381,
#   7902,
#   426,
#   8909,
#   6645,
#   9140,
#   4037,
#   4397,
#   7244,
#   6645,
#   9140,
#   3145,
#   6940],
#  [894,
#   2111,
#   5936,
#   504,
#   8344,
#   720,
#   1160,
#   2784,
#   504,
#   6645,
#   5078,
#   963,
#   7013,
#   3635,
#   6676],
#  [3016, 9418, 942, 6398, 8160, 3593, 9724, 9718, 8505],
#  [8029, 7017],
#  [7149, 2035, 8566, 447, 504, 6645, 9140, 2220, 1660, 9484],
#  [8915, 6558, 1390, 2076, 449, 3489, 6645, 5078, 963, 3177, 6676],
#  [8925, 1348, 8507, 8073, 3424, 8224, 7856, 1048, 9899, 7166, 1348, 2720],
#  [7137, 9952, 7890, 3634, 2476, 5134, 9085, 7137],
#  [8195, 4663, 4108, 4159, 813, 7139, 6452, 5568, 9749, 3398],
#  [7447,
#   6568,
#   7137,
#   6482,
#   3502,
#   813,
#   1502,
#   6956,
#   9498,
#   2185,
#   2582,
#   6645,
#   9140,
#   8995],
#  [9344,
#   1540,
#   6574,
#   1665,
#   2890,
#   1845,
#   6645,
#   6601,
#   963,
#   9344,
#   1540,
#   6574,
#   1665,
#   2890,
#   1845,
#   5381,
#   5078,
#   963,
#   1274,
#   8934,
#   7288],
#  [9061, 6645, 1686, 4686, 6343, 4411, 8875, 2710],
#  [9156,
#   2190,
#   4346,
#   6745,
#   43,
#   104,
#   303,
#   7997,
#   8308,
#   6645,
#   9140,
#   1215,
#   2112,
#   6645,
#   9140,
#   3916,
#   9825],
#  [2663],
#  [1789, 9241, 9470, 7952, 7100, 1846, 5132, 8177, 4221, 5620],
#  [8601, 4852, 9024, 1529, 3179, 1766, 829, 3297, 7750, 8013, 1845, 9350, 471],
#  [6204,
#   7742,
#   7792,
#   5431,
#   9392,
#   555,
#   6360,
#   7374,
#   2085,
#   6645,
#   6883,
#   2340,
#   963,
#   8283,
#   9453,
#   1701],
#  [7174,
#   8744,
#   507,
#   6524,
#   6576,
#   3272,
#   7172,
#   7750,
#   8037,
#   3573,
#   6645,
#   9140,
#   9960,
#   4074,
#   240],
#  [6456, 6794, 2945, 7253, 7234, 8021],
#  [7881, 4175],
#  [504,
#   3356,
#   9474,
#   619,
#   1071,
#   6273,
#   536,
#   3356,
#   2744,
#   6040,
#   6645,
#   9140,
#   2423,
#   9184,
#   8323],
#  [8395, 430, 5974, 3885, 4113, 1270, 507, 4251],
#  [2280, 9200, 9753, 1343, 7414, 4686, 5381, 5078, 963, 7030],
#  [8197,
#   2654,
#   4085,
#   1390,
#   9920,
#   1247,
#   2169,
#   998,
#   6667,
#   8026,
#   1535,
#   8394,
#   6645,
#   6883,
#   4915,
#   963,
#   5588,
#   2654,
#   4085,
#   1390,
#   9920,
#   1247,
#   2169,
#   998,
#   6667,
#   8026,
#   1535,
#   8394,
#   5829,
#   9795,
#   7864,
#   3198,
#   6461,
#   8875,
#   4915],
#  [8934, 6343, 6387, 1679],
#  [4504,
#   7792,
#   7501,
#   3445,
#   3990,
#   8433,
#   9724,
#   9857,
#   6515,
#   9049,
#   7731,
#   6645,
#   3912,
#   2895,
#   963,
#   4063,
#   6940,
#   5680,
#   5940,
#   6940,
#   5731,
#   8981],
#  [5544,
#   9507,
#   3954,
#   5135,
#   3445,
#   4555,
#   721,
#   6645,
#   9140,
#   1830,
#   5731,
#   6645,
#   9140,
#   811],
#  [2695, 3680, 7777, 7275, 362, 3132, 5632, 6645, 9140, 8947],
#  [3799, 8594, 4899, 1673, 661, 9082, 9451, 2990, 895, 983, 5620],
#  [9724,
#   280,
#   8171,
#   8936,
#   5160,
#   5831,
#   9665,
#   5234,
#   6645,
#   9140,
#   4885,
#   6645,
#   9140,
#   8175,
#   7104,
#   6645,
#   9140,
#   3158,
#   9704],
#  [2093,
#   9699,
#   1402,
#   6753,
#   8674,
#   4319,
#   7226,
#   4709,
#   7275,
#   6645,
#   2845,
#   8159,
#   5076,
#   5381,
#   5078,
#   963,
#   1390,
#   9973,
#   7685],
#  [6480, 5130, 1457, 7246, 4159, 4175, 6011, 2102, 7434],
#  [2093, 6516, 9841, 3728, 5627, 9774, 2744, 3193, 9153, 5078, 963, 706, 421],
#  [8627, 1006, 7777, 772, 7724, 7305, 7929, 9325, 3356, 768],
#  [8197, 7206, 841, 9166, 3539, 721, 6645, 2845, 8159, 679],
#  [2589,
#   6493,
#   9818,
#   9421,
#   4911,
#   3264,
#   1710,
#   4911,
#   5923,
#   5064,
#   3279,
#   4629,
#   8434,
#   7699,
#   1820,
#   8885],
#  [2111, 3193],
#  [1186, 6568, 5894, 4555, 1418, 504, 5620],
#  [2359,
#   7536,
#   2742,
#   601,
#   815,
#   9140,
#   6645,
#   9140,
#   2178,
#   6427,
#   6645,
#   9140,
#   2741,
#   9553],
#  [9624, 7511, 5078, 963, 5824, 6676],
#  [6564, 1808, 2359, 2349, 7187, 3075, 5620],
#  [7613,
#   4922,
#   7121,
#   7383,
#   6831,
#   1681,
#   9385,
#   6793,
#   8180,
#   8946,
#   7172,
#   2093,
#   6603,
#   5758],
#  [1150,
#   9447,
#   1666,
#   829,
#   9392,
#   9989,
#   4064,
#   8015,
#   2093,
#   3891,
#   411,
#   6645,
#   9140,
#   8848,
#   9936,
#   6645,
#   9140,
#   3087,
#   3030],
#  [9459,
#   2003,
#   8487,
#   8904,
#   5298,
#   7708,
#   836,
#   9335,
#   5439,
#   6997,
#   5381,
#   5078,
#   963,
#   2134,
#   7165],
#  [3406,
#   2089,
#   9357,
#   6398,
#   3462,
#   6249,
#   5129,
#   3207,
#   5892,
#   5400,
#   6633,
#   601,
#   9392,
#   6249,
#   9752,
#   3939],
#  [6626, 3240, 8330, 9350, 5291, 6645, 1937, 2022, 3240],
#  [4264,
#   7715,
#   9171,
#   2364,
#   8406,
#   3795,
#   8984,
#   30,
#   6665,
#   4932,
#   5381,
#   5078,
#   963,
#   7021,
#   4733,
#   8737],
#  [7022, 9995, 6991, 7881, 7090, 5078, 963, 873, 7138],
#  [1109,
#   5831,
#   7045,
#   1734,
#   3510,
#   5620,
#   7727,
#   6172,
#   7567,
#   6010,
#   2093,
#   5170,
#   1147,
#   5231],
#  [5392, 2364, 1147, 8478, 7100, 7310],
#  [4985, 4759, 2708, 2, 2860, 7048, 3542, 5457, 6645, 9140, 8283, 6022],
#  [8250, 4922, 9194, 5078, 2101, 1845, 1147, 7881, 8120, 8695, 9919],
#  [7063, 8021, 4497],
#  [7827, 1147, 5518, 2, 9042, 9266, 1390, 6384, 8523, 6974, 4463],
#  [1253, 459, 5518, 5908, 5774, 8195],
#  [8369, 2422, 6577, 45, 1833, 3060, 2451],
#  [45,
#   8409,
#   2436,
#   9705,
#   8899,
#   5942,
#   6497,
#   843,
#   6645,
#   9140,
#   1355,
#   6645,
#   9140,
#   3739],
#  [3406,
#   1758,
#   4998,
#   3308,
#   1866,
#   4123,
#   6117,
#   9014,
#   6887,
#   8266,
#   2989,
#   6645,
#   9140,
#   3844,
#   1852,
#   6645,
#   9140,
#   1521,
#   9184],
#  [2382, 9932, 2853, 370, 8737, 6645, 5485, 5625, 2220, 8277],
#  [6493,
#   827,
#   6631,
#   8224,
#   4707,
#   1023,
#   7622,
#   2980,
#   308,
#   3308,
#   8494,
#   8998,
#   2965,
#   1766],
#  [1279, 6878, 3871, 1409, 2744, 5078, 5620],
#  [4108,
#   4403,
#   6627,
#   4190,
#   4190,
#   3504,
#   6645,
#   9140,
#   1682,
#   7693,
#   8505,
#   2684,
#   6286,
#   4484,
#   6243],
#  [8606, 6250],
#  [1659, 3406, 4912, 5443, 1562, 1233, 5378, 8924, 3439],
#  [9225, 1845, 5078, 2362, 8250, 6753, 9687],
#  [1632, 8560, 5078, 1045, 737, 4311, 5381, 5078, 963, 5431, 3198, 8505, 8505],
#  [3308, 4924, 9580, 6645, 9140, 2405, 9788],
#  [4555,
#   3130,
#   7068,
#   1007,
#   3162,
#   4625,
#   6871,
#   8165,
#   6645,
#   9140,
#   3790,
#   5042,
#   5443,
#   6645,
#   9140,
#   681],
#  [9357,
#   9419,
#   7587,
#   504,
#   2547,
#   8559,
#   4039,
#   3006,
#   7750,
#   1643,
#   1054,
#   8077,
#   3462,
#   1253,
#   5510,
#   3602,
#   6524,
#   6645,
#   9140,
#   8705],
#  [6491,
#   3462,
#   4107,
#   7284,
#   1034,
#   5494,
#   8440,
#   7368,
#   269,
#   9233,
#   2506,
#   2990,
#   6805,
#   6879],
#  [1659, 8792, 2185, 5311, 7581, 870, 1448, 6631, 8021, 3398],
#  [6792,
#   1286,
#   2257,
#   5139,
#   6065,
#   5005,
#   4901,
#   4638,
#   2289,
#   998,
#   8160,
#   595,
#   1430,
#   6792],
#  [3004,
#   4923,
#   8929,
#   3274,
#   5731,
#   738,
#   6645,
#   3912,
#   2895,
#   963,
#   4063,
#   5940,
#   6289,
#   1084,
#   6289,
#   5731,
#   5731,
#   6289,
#   5731,
#   6289,
#   6289],
#  [1847, 8250],
#  [1921, 2963, 2227, 6645, 4659, 963],
#  [348, 2275, 6529, 6645, 9140, 73, 6300],
#  [9523, 7638, 6547, 5078, 963, 6468, 9201, 6676],
#  [5373, 1789, 8478, 2977, 9470, 815],
#  [4504, 2282, 2788, 4459, 9590, 756, 1523, 7708, 6522, 6645, 6026, 963, 8204],
#  [4617, 3651, 8497, 3523],
#  [2395, 9276, 6085, 3102, 6343, 3610, 6487, 8250, 1852, 4802, 9435, 5785],
#  [6493,
#   1851,
#   5105,
#   8077,
#   2225,
#   3098,
#   4555,
#   3912,
#   7724,
#   3098,
#   1766,
#   4139,
#   6645,
#   9140,
#   6594],
#  [8827,
#   8796,
#   8827,
#   8796,
#   7172,
#   813,
#   5104,
#   6645,
#   1756,
#   8687,
#   3846,
#   5381,
#   5078,
#   963,
#   8017,
#   1235],
#  [6493,
#   6971,
#   1846,
#   4108,
#   7706,
#   8702,
#   3424,
#   3734,
#   7332,
#   4722,
#   6645,
#   9140,
#   958,
#   6343,
#   5384],
#  [9966, 357, 3933, 7286, 1282],
#  [7903,
#   4686,
#   3198,
#   4003,
#   7212,
#   6012,
#   8277,
#   7903,
#   883,
#   3198,
#   883,
#   3770,
#   6645,
#   6883,
#   2340,
#   963,
#   8283,
#   9224,
#   5381,
#   5078,
#   963,
#   6093,
#   2109],
#  [9169, 3635, 7576, 5510, 9767],
#  [7750, 8387, 1286, 2369, 846, 8790, 5078, 963, 216, 2740, 3981],
#  [5851,
#   6128,
#   7572,
#   7711,
#   625,
#   1244,
#   7121,
#   7881,
#   4225,
#   7712,
#   6645,
#   9184,
#   8560,
#   7392,
#   2482,
#   2779,
#   4063,
#   3981,
#   6689,
#   8069,
#   8621,
#   3258,
#   5337,
#   6723,
#   3670,
#   1194,
#   2846,
#   9426,
#   4789,
#   1695,
#   95,
#   7272,
#   6561,
#   1687,
#   7658,
#   415],
#  [1118, 6125, 373, 1116, 7536, 2365, 3350, 7137, 6645, 9140, 5727, 5693],
#  [8021, 6480, 9839, 6508, 1023, 5002, 4142, 4690, 1554],
#  [8195, 6642, 1666, 5001, 721, 8507, 3462, 2041],
#  [1209, 7172, 8127, 9945, 4375, 2935],
#  [2708, 6538, 8733, 5078, 963, 341, 6676],
#  [4504, 9362, 9149, 4352, 6645, 5078, 963, 2541, 6676, 5105],
#  [7149, 5786, 9447, 4269, 6645, 1937, 6203, 3198, 5569],
#  [5443,
#   2662,
#   5443,
#   9755,
#   3193,
#   5443,
#   177,
#   7166,
#   9752,
#   2093,
#   815,
#   6645,
#   9140,
#   6694,
#   9418,
#   450],
#  [4401,
#   7501,
#   9724,
#   5271,
#   2873,
#   9724,
#   4642,
#   7528,
#   9410,
#   5271,
#   9276,
#   2789,
#   1227],
#  [3272, 7731, 157, 2850, 5283, 4934, 6645, 9140, 1732],
#  [5923,
#   498,
#   8405,
#   871,
#   5589,
#   6564,
#   9850,
#   108,
#   6665,
#   774,
#   6645,
#   3912,
#   2895,
#   963,
#   4063,
#   5940,
#   6289,
#   5940,
#   5731,
#   5940,
#   1084],
#  [9763, 813, 4527, 5942, 7487, 2010],
#  [4725,
#   9465,
#   7881,
#   9689,
#   2423,
#   1701,
#   9556,
#   6645,
#   9140,
#   6012,
#   4686,
#   6645,
#   9140,
#   1701,
#   6295,
#   6645,
#   9140,
#   5214,
#   6343],
#  [7501, 642, 6080, 2016, 1845, 2016, 9265],
#  [193, 3921, 9599, 3864, 8871, 8134, 1552, 7638, 9276],
#  [4503,
#   411,
#   2970,
#   7772,
#   2744,
#   815,
#   2990,
#   8848,
#   557,
#   6645,
#   9140,
#   7125,
#   3522,
#   6645,
#   9140,
#   1342],
#  [9426,
#   7723,
#   9528,
#   2977,
#   4566,
#   8627,
#   4456,
#   1443,
#   3205,
#   8371,
#   6645,
#   9140,
#   3333,
#   5847],
#  [5869, 1044, 5776, 422, 5642, 5537, 3116, 8281, 3379, 9754, 6290, 7938],
#  [5831,
#   480,
#   4970,
#   303,
#   3495,
#   6645,
#   6729,
#   963,
#   7207,
#   5942,
#   3566,
#   6645,
#   6729,
#   963,
#   7207,
#   5381,
#   5078,
#   963,
#   3307,
#   6343,
#   4419],
#  [9114,
#   6920,
#   3193,
#   7139,
#   8180,
#   5544,
#   4949,
#   9799,
#   9489,
#   5591,
#   6645,
#   9140,
#   5738,
#   6645,
#   9140,
#   3691,
#   6343],
#  [7049,
#   2084,
#   7896,
#   364,
#   3651,
#   6096,
#   4159,
#   3190,
#   6841,
#   1699,
#   5944,
#   6645,
#   9140,
#   8934,
#   3066],
#  [9115,
#   7252,
#   461,
#   6493,
#   6255,
#   8029,
#   1646,
#   1833,
#   907,
#   2447,
#   3998,
#   5443,
#   7414,
#   3169,
#   7980,
#   5381,
#   5078,
#   963,
#   2003,
#   5940],
#  [8361, 9887, 5084, 9392, 9970, 5518, 3462, 3783],
#  [8665, 642, 5865, 1195, 4689, 6774, 3651, 2745, 5271, 923],
#  [4357, 6829, 2582, 642, 6386, 294, 5078, 963, 2434, 6676],
#  [3583,
#   4159,
#   5757,
#   7501,
#   2175,
#   6511,
#   5854,
#   9097,
#   6511,
#   5086,
#   6968,
#   8646,
#   6526,
#   2970,
#   2411,
#   9233,
#   6645,
#   9140,
#   3402],
#  [3909, 4159, 949, 9013, 9227, 4829, 3573, 6645, 9140, 8427, 4951, 9280],
#  [1826, 642, 4683, 6204, 162],
#  [7721,
#   3207,
#   6128,
#   9930,
#   6522,
#   2451,
#   1808,
#   9562,
#   1035,
#   5012,
#   8595,
#   5162,
#   3497,
#   7721,
#   5381,
#   5078,
#   963,
#   5419],
#  [8195, 6557, 4108, 8800, 155, 9596],
#  [9791, 3445, 9385, 7175, 7175, 7175, 9314],
#  [5668,
#   1151,
#   1166,
#   774,
#   2010,
#   9970,
#   9123,
#   4175,
#   6753,
#   8250,
#   5443,
#   1337,
#   9945,
#   6740],
#  [1846, 447, 4423, 1390, 4378, 5378, 4159, 5869, 6645, 9140, 905, 9656],
#  [3099, 4159, 498, 9980, 7619, 7792, 8178, 3950, 5908, 2550, 6645, 9140, 3959],
#  [4555,
#   2196,
#   5620,
#   358,
#   6142,
#   601,
#   4605,
#   2089,
#   5830,
#   1808,
#   4165,
#   9336,
#   759,
#   8531],
#  [7615, 816, 7576, 6645, 9140, 4570],
#  [237,
#   4555,
#   8171,
#   9647,
#   601,
#   5900,
#   9392,
#   2744,
#   4011,
#   1583,
#   5400,
#   6645,
#   9140,
#   6266,
#   6645,
#   9140,
#   7181],
#  [9057,
#   2303,
#   7063,
#   7856,
#   2225,
#   6769,
#   9385,
#   8250,
#   4352,
#   8989,
#   9232,
#   2093,
#   2070,
#   595,
#   1860],
#  [2470, 9497, 6080, 4954, 5400, 2262, 6096, 2364, 1147, 7166, 4555, 7308],
#  [5668,
#   4958,
#   2508,
#   9832,
#   3799,
#   8306,
#   1188,
#   2176,
#   4839,
#   4395,
#   2095,
#   4062,
#   5078,
#   963,
#   6874],
#  [3283,
#   7000,
#   8409,
#   5911,
#   2903,
#   3874,
#   6645,
#   9140,
#   5254,
#   8071,
#   8505,
#   8091,
#   6645,
#   9140,
#   4049],
#  [1034,
#   6049,
#   108,
#   8967,
#   9048,
#   7162,
#   4706,
#   6645,
#   9140,
#   3464,
#   6645,
#   9140,
#   9184,
#   3589],
#  [8197, 9166, 3539, 721, 6645, 2845, 8159, 679],
#  [1659, 9190, 4555, 3864, 8340, 7939, 5443, 3872],
#  [4070, 1048, 3573, 9444, 6645, 3470, 963, 8934, 6879, 8875, 3470],
#  [6558, 4922, 9791, 1852, 5096, 7172],
#  [8823],
#  [6457,
#   4175,
#   1270,
#   6363,
#   1366,
#   5643,
#   725,
#   6645,
#   9140,
#   2599,
#   8979,
#   6645,
#   9140,
#   6343,
#   7214],
#  [3062, 7688, 716],
#  [357, 3406, 9282, 3462, 2093, 9392, 2298, 6645, 9140, 3294, 8195],
#  [5513, 1109, 8897, 8028, 504, 4175, 8687, 9410, 8665],
#  [4155, 2303, 2278, 9357, 6373, 8013, 5097, 4912, 6645, 9140, 5995, 1050],
#  [6493,
#   1782,
#   8272,
#   9200,
#   2052,
#   6128,
#   9951,
#   3950,
#   6281,
#   6645,
#   9140,
#   8296,
#   3087],
#  [6560,
#   7501,
#   8611,
#   1869,
#   5659,
#   4467,
#   5168,
#   6645,
#   9140,
#   5742,
#   5254,
#   2467,
#   6645,
#   9140,
#   3198,
#   7217,
#   4686],
#  [6193, 1630, 8871, 4367, 4367, 9200, 5378],
#  [5241, 4010, 9518, 2617, 7070, 9988, 1244, 8772, 6645, 1937, 3161],
#  [4159,
#   6215,
#   8222,
#   4476,
#   7939,
#   249,
#   370,
#   1907,
#   6645,
#   9140,
#   1838,
#   6645,
#   9140,
#   9833],
#  [6465, 5831, 9153, 5078, 963, 3369, 1361, 2296],
#  [9730, 1071, 5387, 2093, 1462, 5078, 963, 8283, 5095, 5634],
#  [9970],
#  [6142, 9841, 9720, 8654, 6645, 330, 6661],
#  [1058,
#   9153,
#   8642,
#   7536,
#   3651,
#   8902,
#   5510,
#   5494,
#   2999,
#   4899,
#   759,
#   4163,
#   5078,
#   963,
#   4786,
#   245],
#  [6409,
#   6728,
#   2905,
#   4686,
#   6851,
#   3593,
#   6645,
#   1686,
#   4686,
#   5026,
#   6726,
#   1824,
#   8875,
#   2710],
#  [6465, 6128, 9933],
#  [2744,
#   815,
#   5007,
#   8826,
#   6808,
#   3198,
#   8629,
#   6645,
#   9140,
#   325,
#   3088,
#   6645,
#   9140,
#   2514,
#   6645,
#   9140,
#   541,
#   3514],
#  [59,
#   6784,
#   8507,
#   4036,
#   3938,
#   9055,
#   2970,
#   6645,
#   9140,
#   6581,
#   3896,
#   6645,
#   9140,
#   6065,
#   7273],
#  [7870,
#   460,
#   2435,
#   2773,
#   6573,
#   5387,
#   9521,
#   1475,
#   5815,
#   991,
#   7872,
#   5078,
#   963,
#   2131],
#  [7246, 4159, 8263, 2547, 6524, 6645, 9140, 8997, 2296, 5153, 7589],
#  [7939, 8435, 8969, 555, 1688, 6645, 9140, 397, 6289],
#  [3593, 3396, 9350, 6532, 9945, 5971, 1894, 5279, 5078, 963, 9719, 8426],
#  [1546,
#   6176,
#   4344,
#   938,
#   6176,
#   7706,
#   6645,
#   183,
#   8159,
#   7707,
#   2542,
#   2671,
#   6645,
#   183,
#   8159,
#   8921],
#  [1530, 9549, 6645, 5078, 963, 5524, 6676],
#  [9891,
#   1286,
#   815,
#   7315,
#   8783,
#   1278,
#   9392,
#   6502,
#   2093,
#   1788,
#   1448,
#   6645,
#   9140,
#   8488,
#   6645,
#   9140,
#   144],
#  [2942, 5851, 8440, 395, 3272, 2550, 6645, 9140, 5429, 5909],
#  [2722,
#   2059,
#   1161,
#   4629,
#   6645,
#   6883,
#   2710,
#   963,
#   9724,
#   4063,
#   2230,
#   2072,
#   328,
#   4686,
#   1147,
#   4504,
#   3492,
#   611,
#   7172,
#   7172],
#  [8949, 7957, 9851, 7957, 9851, 6188, 1236, 5078, 963, 1701, 5641, 8947],
#  [9873, 7432, 9227, 1907],
#  [4592, 7100, 1309, 8182, 9687, 3939, 5589, 3820],
#  [5105,
#   2592,
#   4110,
#   5105,
#   9165,
#   1056,
#   4517,
#   5668,
#   9832,
#   607,
#   5210,
#   4166,
#   9184,
#   6645,
#   5078,
#   963,
#   1888,
#   6676,
#   5105],
#  [94, 2244, 2822, 94, 9164, 7622, 1665, 6207, 2077, 5620],
#  [4079,
#   1962,
#   6452,
#   9575,
#   258,
#   2619,
#   2550,
#   994,
#   5854,
#   6645,
#   9140,
#   94,
#   575,
#   6645,
#   9140,
#   872],
#  [6667,
#   1879,
#   9953,
#   3382,
#   759,
#   9241,
#   7207,
#   9813,
#   6667,
#   1879,
#   9953,
#   9041,
#   8235,
#   9899],
#  [4852,
#   4108,
#   9858,
#   6902,
#   1529,
#   6300,
#   6477,
#   1793,
#   2130,
#   6645,
#   9140,
#   6716,
#   4686,
#   3954,
#   6645,
#   9140,
#   9184,
#   9197,
#   8456],
#  [5400,
#   1054,
#   2744,
#   3092,
#   7839,
#   1789,
#   6956,
#   6645,
#   9140,
#   5695,
#   2848,
#   6645,
#   9140,
#   9892,
#   3630],
#  [5668,
#   9832,
#   8995,
#   6894,
#   4110,
#   6645,
#   2108,
#   9851,
#   963,
#   6480,
#   4455,
#   981,
#   5078,
#   963,
#   3266,
#   113],
#  [6493,
#   8962,
#   2883,
#   1679,
#   4148,
#   7053,
#   9891,
#   1286,
#   6645,
#   9140,
#   3125,
#   8875,
#   2710,
#   2296,
#   2624,
#   752,
#   6879,
#   4640],
#  [8284,
#   2300,
#   9970,
#   6487,
#   8433,
#   4175,
#   3703,
#   7743,
#   6340,
#   8433,
#   3864,
#   1071,
#   6466,
#   5407,
#   7550,
#   632],
#  [1845, 8646, 9939, 3645, 3651, 4079, 3544, 5444, 5078, 963, 2281, 9392],
#  [1564,
#   759,
#   5942,
#   6577,
#   9884,
#   841,
#   6645,
#   7057,
#   9552,
#   5381,
#   5078,
#   963,
#   6220,
#   1494],
#  [3974, 721, 3665, 6940, 172, 6940, 8183, 6920, 7968],
#  [5206, 3308, 2230, 1703, 7757, 2720, 6645, 9140, 9047, 6343, 293],
#  [8874, 7864, 721, 6645, 5078, 963, 2941, 6676],
#  [2743,
#   309,
#   871,
#   9201,
#   871,
#   1901,
#   2043,
#   83,
#   7234,
#   1174,
#   8935,
#   1694,
#   445,
#   2917],
#  [8022, 8330, 9957, 9922, 1463, 7908, 8325, 8250, 8383],
#  [8416,
#   8306,
#   2052,
#   492,
#   6487,
#   6645,
#   9140,
#   5940,
#   9147,
#   498,
#   473,
#   1250,
#   8622,
#   7594,
#   5257,
#   6645,
#   9140,
#   8737,
#   2669],
#  [7571, 6732, 8733, 5078, 963, 5819, 6676],
#  [5256, 3320, 9214, 8816, 3136, 8173, 6340, 6665, 6680, 6645, 9140, 8989],
#  [5910, 9217, 4175, 6685, 5400],
#  [4922,
#   3665,
#   2669,
#   15,
#   642,
#   6331,
#   3912,
#   4490,
#   6532,
#   4922,
#   2945,
#   6857,
#   3103,
#   5942,
#   15,
#   7077,
#   3015,
#   6645,
#   9140,
#   4470,
#   4704],
#  [9082,
#   3362,
#   1590,
#   3673,
#   3643,
#   7630,
#   7560,
#   4159,
#   1837,
#   6267,
#   1577,
#   5241,
#   6645,
#   9140,
#   1337,
#   5443,
#   3292,
#   8981,
#   4284,
#   8310,
#   8283],
#  [9057, 3499, 6142, 6027, 3298, 3959, 1402, 6645, 9140, 4063, 5637, 4987],
#  [508,
#   5714,
#   9661,
#   9705,
#   3991,
#   9516,
#   1407,
#   9627,
#   2446,
#   8575,
#   6169,
#   1638,
#   6645,
#   9140,
#   3198,
#   2443],
#  [9850, 6480, 6645, 5078, 963, 7012, 6676],
#  [5942,
#   7855,
#   6522,
#   1147,
#   2828,
#   5817,
#   2772,
#   4633,
#   3912,
#   2704,
#   1852,
#   5105,
#   6645,
#   9140,
#   5731,
#   6416,
#   6645,
#   9140,
#   2722,
#   8202],
#  [2813, 2009, 2813, 8077, 9851, 2813, 721, 2813, 2663, 2813, 2550],
#  [3406,
#   1118,
#   30,
#   338,
#   3320,
#   2519,
#   2359,
#   815,
#   6645,
#   9140,
#   9677,
#   1991,
#   6645,
#   9140,
#   8292],
#  [7701, 1826, 6588, 5381, 5078, 963, 9438, 8199],
#  [8909, 7581, 1147, 6373, 6128, 4206, 9661, 3104, 4611, 772],
#  [695, 6465, 6289, 5842, 1191, 6645, 1937, 595, 5381, 5078, 963, 9279, 8505],
#  [8778,
#   1119,
#   15,
#   2230,
#   1776,
#   2365,
#   3205,
#   2093,
#   6784,
#   3198,
#   7691,
#   8209,
#   6645,
#   6883,
#   7707,
#   9140,
#   2141,
#   8674,
#   1483,
#   7889,
#   813],
#  [8842,
#   3548,
#   6707,
#   1457,
#   4525,
#   642,
#   9948,
#   8077,
#   6417,
#   8310,
#   7110,
#   3926,
#   6831,
#   3926,
#   9350],
#  [7783, 8969, 2965, 479],
#  [5620, 9993, 5620, 5832, 8310, 1926, 1186, 2364, 1684, 6765, 894, 1083, 894],
#  [2137, 3406, 3266, 6546, 3813, 8059, 2550, 2512, 6645, 9140, 648, 9752, 1965],
#  [8408,
#   1646,
#   7048,
#   8935,
#   4107,
#   815,
#   9652,
#   7162,
#   9337,
#   1326,
#   1206,
#   6645,
#   9140,
#   4413,
#   7410,
#   6645,
#   9140,
#   4619],
#  [6493,
#   4767,
#   6049,
#   4970,
#   6865,
#   8199,
#   2822,
#   9193,
#   2115,
#   6645,
#   8582,
#   8159,
#   2552,
#   7465,
#   4372,
#   5381,
#   5078,
#   963,
#   5324],
#  [351, 8433, 1966, 1966, 1966, 3722, 6645, 9140, 316, 4737, 7160],
#  [4496, 1568, 5381, 5078, 963, 2086],
#  [2500, 1577, 8923, 3132, 9034, 7166, 3719, 9718, 6645, 9140, 9930, 1843],
#  [6568, 792, 5366, 4383, 6645, 6883, 2340, 963, 8283, 9696, 4063],
#  [2653,
#   7615,
#   5367,
#   5887,
#   6645,
#   9140,
#   2220,
#   7304,
#   5073,
#   6645,
#   9140,
#   5198,
#   7459],
#  [8902, 9383, 6143, 4060, 202],
#  [3873,
#   1326,
#   1059,
#   7016,
#   6995,
#   7403,
#   5892,
#   2081,
#   5664,
#   1326,
#   9983,
#   6645,
#   1373,
#   9220,
#   7812],
#  [6950,
#   7286,
#   4836,
#   5693,
#   5477,
#   9373,
#   4125,
#   2041,
#   6645,
#   9140,
#   1394,
#   6645,
#   9140,
#   2641,
#   5761],
#  [690, 5078, 963, 8441, 6676],
#  [8771, 7022, 841, 2172, 276, 4133, 3574, 5139, 151, 957, 611, 2131],
#  [810,
#   6776,
#   6901,
#   9945,
#   7172,
#   5371,
#   4159,
#   8790,
#   8304,
#   8997,
#   108,
#   6645,
#   9140,
#   6568,
#   9997],
#  [5378, 6645, 5078, 963, 8293, 6676],
#  [8507, 1666, 2396, 9464, 3283, 6645, 5078, 963, 4346, 6676],
#  [7425,
#   4899,
#   2483,
#   1808,
#   6001,
#   6884,
#   6001,
#   6884,
#   8140,
#   5208,
#   6645,
#   6883,
#   2340,
#   963,
#   8283,
#   1617],
#  [1054, 6764, 9276, 2257, 2106, 6452, 364, 4911, 2489],
#  [8505,
#   3912,
#   1054,
#   8433,
#   6479,
#   6680,
#   673,
#   9774,
#   6645,
#   9140,
#   8365,
#   6645,
#   9140,
#   6647,
#   7717],
#  [1147,
#   3574,
#   5009,
#   4504,
#   2012,
#   4829,
#   6868,
#   5114,
#   5088,
#   1159,
#   5672,
#   8153,
#   690,
#   2925],
#  [639, 7874, 1800, 9107, 8772, 5443, 2423, 2131],
#  [9667, 3278, 4912, 1174, 3864, 1150, 2742, 3991, 5524, 3516, 2556, 3735],
#  [8340, 1081, 8408, 328, 1869, 3633, 5464, 6645, 9140, 9923],
#  [8624,
#   5923,
#   157,
#   2349,
#   1123,
#   3398,
#   4881,
#   7454,
#   6645,
#   9140,
#   343,
#   6645,
#   9140,
#   7693,
#   727,
#   4065],
#  [2742, 8250, 370],
#  [7001,
#   3917,
#   1764,
#   411,
#   8905,
#   348,
#   9828,
#   6645,
#   9140,
#   1091,
#   41,
#   6645,
#   9140,
#   7462,
#   8694,
#   8505],
#  [2009, 759, 2957, 6645, 9140, 9921, 4141],
#  [2016, 721],
#  [2710, 2789],
#  [2093, 2349, 5936, 6645, 9140, 3035],
#  [5538, 7575, 6753, 6603, 6753, 6603, 597, 1758, 7403, 6493, 9013],
#  [9724],
#  [4922,
#   9820,
#   9057,
#   5942,
#   1735,
#   2093,
#   7770,
#   9948,
#   8640,
#   1734,
#   6645,
#   7542,
#   3103,
#   3288,
#   5381,
#   5078,
#   963,
#   5708,
#   6215,
#   1995],
#  [7205,
#   6350,
#   1845,
#   4367,
#   5096,
#   9549,
#   6645,
#   471,
#   6350,
#   4367,
#   8120,
#   6645,
#   2845,
#   8159,
#   9983,
#   333],
#  [8870, 5968, 5631, 2364],
#  [9182, 2797, 348, 108, 6468, 6477, 3016],
#  [3092, 7739, 4221, 205, 4621, 4064, 3831, 2093, 7830, 7739, 793, 4286],
#  [3873, 1444, 8250, 4517],
#  [1870, 7159, 9169, 546, 5381, 5078, 963, 5644],
#  [9765, 6645, 5078, 963, 1873, 6676],
#  [5234, 2873, 551, 1075, 1807, 3167, 1805, 3427, 2262],
#  [6062, 1865, 5170, 4677, 6062, 5381, 5078, 963, 7024, 1914, 8160],
#  [5942,
#   2183,
#   4010,
#   9615,
#   1233,
#   7633,
#   2422,
#   6645,
#   9140,
#   6289,
#   470,
#   6645,
#   9140,
#   1701,
#   6295,
#   6645,
#   9140,
#   2266,
#   8426],
#  [7200, 9617, 607, 2532, 1716, 9833, 437, 3080, 9639, 7238, 4829, 5620],
#  [1320, 577, 8013, 5092, 2434, 4108, 4403, 5538, 663],
#  [5191, 2253, 8171, 642, 9999, 3898, 6645, 9140, 4283],
#  [7947,
#   4471,
#   8437,
#   8782,
#   1652,
#   2701,
#   2625,
#   8148,
#   4316,
#   6645,
#   183,
#   8159,
#   8193,
#   4372,
#   5381,
#   5078,
#   963,
#   2064,
#   9287],
#  [6577,
#   7045,
#   1923,
#   870,
#   3246,
#   5431,
#   3064,
#   6645,
#   183,
#   8159,
#   6289,
#   8854,
#   6298,
#   7406,
#   2829,
#   3672],
#  [7992],
#  [1764, 445, 9061, 1366, 9718, 6645, 9140, 3558],
#  [1643,
#   9357,
#   204,
#   6675,
#   9350,
#   6853,
#   6805,
#   2394,
#   3006,
#   8784,
#   9899,
#   3406,
#   5940,
#   6645,
#   9140,
#   9822],
#  [1789, 3864, 4669, 1758, 4476, 357, 108, 5620],
#  [5390, 5942, 3519, 4835, 5381, 5078, 963, 316, 9902],
#  [4442, 6645, 5078, 963, 1092, 6676],
#  [2137, 4663, 6665, 5987, 6914, 894, 6645, 9140, 9193],
#  [437,
#   3467,
#   2364,
#   2122,
#   1533,
#   8863,
#   8177,
#   7137,
#   2515,
#   9587,
#   3594,
#   3664,
#   2364,
#   5381,
#   5078,
#   963,
#   1719],
#  [6258,
#   3628,
#   7392,
#   2,
#   881,
#   7556,
#   6645,
#   2630,
#   963,
#   8250,
#   2813,
#   7082,
#   3298,
#   695,
#   562,
#   2517],
#  [247, 7939, 9057, 6991, 657, 59],
#  [4917, 6645, 9140, 2489, 4686, 9962],
#  [9354, 7711, 4154, 276, 5264, 1902, 8181, 9051, 7975, 5078, 963, 6722, 9771],
#  [9064, 3028, 3016],
#  [998,
#   4133,
#   7807,
#   5597,
#   2488,
#   9765,
#   179,
#   6645,
#   9140,
#   8101,
#   9253,
#   6645,
#   9140,
#   1913,
#   1164],
#  [8021, 1373, 1530, 8469],
#  [3098, 830, 7768, 3262, 1687, 7778, 1292, 6645, 9140, 177, 8875, 2451],
#  [24,
#   446,
#   2654,
#   6645,
#   5697,
#   963,
#   24,
#   5347,
#   2093,
#   1649,
#   2122,
#   9516,
#   5347,
#   6645,
#   1379,
#   9140,
#   4372,
#   3483,
#   5731,
#   5117],
#  [563, 7487, 2077, 1564, 3272, 3519, 7172],
#  [9728, 7159, 1374, 6768, 30, 644, 5311],
#  [1019,
#   65,
#   7567,
#   2865,
#   6314,
#   9282,
#   1234,
#   6645,
#   482,
#   963,
#   6645,
#   5485,
#   5625,
#   8459],
#  [7721,
#   3335,
#   4861,
#   1826,
#   642,
#   8012,
#   9344,
#   5814,
#   4861,
#   4861,
#   4861,
#   8687,
#   9763,
#   8326,
#   3709,
#   6645,
#   8082,
#   9140,
#   4063,
#   3106,
#   5767],
#  [9005, 6573, 8897, 6701, 6645, 9140, 1542],
#  [7064,
#   4266,
#   8478,
#   5141,
#   252,
#   7757,
#   9767,
#   5379,
#   8117,
#   389,
#   5166,
#   4266,
#   8540,
#   4518,
#   8198],
#  [5564, 9200, 1915, 5562, 1111, 8799, 8298],
#  [2012, 23, 6645, 3912, 2895, 963, 4063, 6289, 9989],
#  [4193, 5668, 9832, 3971, 9871, 5381, 5078, 963, 9462, 7696, 238],
#  [2708, 6645, 5078, 963, 4173, 6676],
#  [8160,
#   2894,
#   2720,
#   2349,
#   4743,
#   2744,
#   6574,
#   3,
#   3398,
#   7048,
#   6645,
#   9140,
#   7135,
#   3394,
#   5620],
#  [816, 1119, 1755, 2842, 5958, 5157, 586, 4272, 6645, 2692, 3328, 963, 9615],
#  [7895, 3016],
#  [2744,
#   7166,
#   8674,
#   1782,
#   4221,
#   4495,
#   8109,
#   5114,
#   4555,
#   8222,
#   2744,
#   5323,
#   326,
#   1782,
#   9899],
#  [2041, 2742, 6474, 9547, 664, 7284, 2014, 6890, 8947, 2131],
#  [4623, 3955, 8936, 2908, 9028, 5387, 2015],
#  [4352,
#   8254,
#   3102,
#   4290,
#   2402,
#   4344,
#   2489,
#   6831,
#   9447,
#   2797,
#   1054,
#   7831,
#   5443,
#   8870,
#   7831,
#   3102],
#  [6686, 1081, 8897, 1112, 5078, 963, 5712],
#  [9468, 1274, 4912],
#  [4059, 9516, 5451, 5940, 6682, 7896, 5923, 6645, 8082, 9140, 4063, 7417],
#  [7048,
#   3633,
#   3126,
#   5962,
#   1019,
#   7275,
#   3967,
#   4555,
#   7032,
#   919,
#   7048,
#   5544,
#   3311,
#   3126,
#   319,
#   9899],
#  [3060,
#   5960,
#   5132,
#   647,
#   1666,
#   7022,
#   5547,
#   9528,
#   6645,
#   9140,
#   5270,
#   8875,
#   3801,
#   6645,
#   9140,
#   8618,
#   654],
#  [8587, 8826, 8454, 108, 3837, 4761, 584, 3396, 5974, 3016],
#  [6618, 2966, 4286, 5865, 782, 155, 3055, 5620],
#  [2010, 3603, 9268, 6645, 5078, 963, 8091, 6676],
#  [5058, 5936, 2157, 6645, 5078, 963, 544, 6676],
#  [4429, 3033, 5835, 3938, 2288, 9133, 6645, 9140, 3198, 2220, 7897, 1608],
#  [7477, 1250, 1054, 7039, 7454, 6820, 7026, 3132, 9005, 5620],
#  [2663, 1734, 5381, 5078, 963, 5246],
#  [8587, 7314, 734, 4836, 813, 7757, 2908, 6314, 1081, 3016],
#  [8993, 7300, 1542, 4027, 6645, 9140, 5054, 8421, 6645, 9140, 3849, 3529],
#  [5196, 9124, 9810, 2433, 8576, 8283, 8283, 4498, 2, 6645, 9140, 5155, 1445],
#  [7305, 3670, 312, 5114, 2, 2111, 1709, 3510, 6680, 6645, 9140, 3264],
#  [7375, 4018, 4245, 8108, 1869, 6645, 9140, 6811, 9420, 5940],
#  [9561,
#   795,
#   2894,
#   1323,
#   9064,
#   9763,
#   8935,
#   870,
#   6355,
#   6645,
#   9140,
#   3458,
#   2906,
#   6645,
#   9140,
#   6202],
#  [4159,
#   2654,
#   8744,
#   8935,
#   721,
#   1048,
#   6568,
#   3075,
#   5195,
#   7287,
#   4344,
#   8434,
#   6645,
#   9140,
#   2064,
#   5498,
#   5254],
#  [4264, 2614, 1511, 6645, 5078, 963, 9021, 6676],
#  [8177,
#   6493,
#   5603,
#   5518,
#   2081,
#   3734,
#   914,
#   3575,
#   2633,
#   1698,
#   7403,
#   6493,
#   642,
#   3574,
#   894,
#   6255,
#   6581],
#  [8936, 9798, 157, 4484, 1483, 1350, 4027, 6645, 9140, 267, 9539, 4063],
#  [368,
#   6142,
#   6630,
#   3298,
#   7162,
#   2402,
#   4785,
#   6974,
#   4912,
#   4991,
#   6645,
#   9140,
#   5885,
#   8458],
#  [9205, 9447, 6701],
#  [2987,
#   4010,
#   1852,
#   3126,
#   1270,
#   4311,
#   8195,
#   6556,
#   8874,
#   8679,
#   6645,
#   330,
#   5336,
#   9049,
#   5940],
#  [6374,
#   934,
#   2662,
#   608,
#   4899,
#   1966,
#   3899,
#   3602,
#   3092,
#   8674,
#   4159,
#   3899,
#   6128,
#   8108,
#   8310,
#   6645,
#   9140,
#   5339,
#   1645],
#  [9791, 3985, 6138, 5775, 7501, 4110, 5743, 5078, 963, 1802, 6676],
#  [9811, 6493, 811, 3162, 3130, 8872, 1643, 7383, 9948, 7454, 6645, 9140, 9517],
#  [1846, 1054, 642, 3734, 7332, 5170, 3575, 5072, 1390, 3151],
#  [6493,
#   3643,
#   4170,
#   1562,
#   5387,
#   9041,
#   2903,
#   6432,
#   5795,
#   2141,
#   6645,
#   9140,
#   4063,
#   4334,
#   1701,
#   6645,
#   9140,
#   7465,
#   674,
#   2220],
#  [9276, 8818, 3291, 4443, 302, 2364, 7172, 5381, 5078, 963, 2727, 2896, 4686],
#  [1799, 1054, 2800, 5372, 3100, 907, 1546, 1845, 7881, 9954, 5078, 963, 2925],
#  [2744,
#   6026,
#   5510,
#   5464,
#   7096,
#   2395,
#   3928,
#   8643,
#   8507,
#   8967,
#   4555,
#   9070,
#   2519,
#   6645,
#   9140,
#   4063,
#   3271,
#   8934,
#   6289],
#  [5831,
#   6493,
#   6493,
#   3297,
#   9233,
#   6645,
#   9140,
#   9752,
#   6645,
#   9140,
#   9752,
#   6645,
#   9140,
#   6343,
#   8044],
#  [1054, 9624, 5731, 5971, 2101, 642, 9622, 5078, 963, 3555, 8045],
#  [649, 15, 9314, 6027],
#  [1540,
#   4010,
#   7501,
#   8642,
#   9268,
#   1021,
#   9588,
#   2970,
#   6645,
#   8533,
#   4003,
#   4713,
#   8875,
#   301,
#   4969,
#   1540],
# ...
#   6225,
#   2093,
#   7498],
#  [674, 6314, 474, 3518, 2752, 5620],
#  [4293, 7172, 8459, 6645, 5078, 963, 9520, 6676],
#  [2496, 567, 6657, 8442, 2695, 1515, 921],
#  [9315, 8274, 9841, 3162, 7778, 1847, 5278, 451, 8859, 6645, 9140, 2220, 2228],
#  [7623, 6782, 6142, 5831, 5738, 8272, 1498],
#  [565, 9306, 4683],
#  [8313,
#   6267,
#   3080,
#   9699,
#   5942,
#   1096,
#   119,
#   9747,
#   2016,
#   4375,
#   4352,
#   5510,
#   5620,
#   9385,
#   3489],
#  [8195,
#   5620,
#   7381,
#   811,
#   5631,
#   1366,
#   3398,
#   8223,
#   3341,
#   5908,
#   1781,
#   9006,
#   6645,
#   2845,
#   8159,
#   1594,
#   5714],
#  [3024, 4286, 5936, 4018, 4375, 8407, 5381, 5078, 963, 2449, 5080, 4834],
#  [8679, 1056, 5080, 1390, 3269, 5416, 6344, 6866, 275],
#  [2357, 3298, 2282, 6645, 9140, 2371],
#  [3593, 2550, 4061, 6645, 9140, 6751, 5012],
#  [7671, 1923, 117, 9243, 755, 3093, 2230],
#  [5321,
#   157,
#   2758,
#   2451,
#   3104,
#   6645,
#   2845,
#   8159,
#   7135,
#   5381,
#   5078,
#   963,
#   4326,
#   3275],
#  [1304, 5690, 3564, 9530, 3564, 1847, 6368, 8560, 7397, 4852, 9919, 8695],
#  [8250,
#   4899,
#   717,
#   3873,
#   8564,
#   3191,
#   9034,
#   3453,
#   8540,
#   6992,
#   5933,
#   6645,
#   6883,
#   2340,
#   963,
#   8283,
#   7039,
#   9186],
#  [1116,
#   4110,
#   508,
#   348,
#   3787,
#   4442,
#   9316,
#   5564,
#   8107,
#   963,
#   7619,
#   348,
#   3787,
#   4442,
#   9316,
#   86],
#  [7792, 9945, 3205, 6645, 9140, 6611],
#  [1023, 9732, 6128, 4517, 6649, 5078, 963, 8778, 2533],
#  [8041, 8975, 755, 1823],
#  [7432, 54, 6645, 5078, 963, 8767, 6676],
#  [8358, 1552, 3061, 5078, 963, 361, 9998, 3423],
#  [9097, 7953, 2930, 4516, 2257, 5381, 5078, 963, 4042, 5940],
#  [6128, 7939, 9140, 1150, 2015, 5115, 5078, 963, 2224],
#  [8321, 4566, 655, 4728, 4969, 2414, 5620],
#  [5725, 5439, 9730, 1845, 9747, 5725, 4993],
#  [4811, 9215, 1166],
#  [3632, 8197, 3367, 4319, 1329, 9734, 5739, 8582, 8159, 4063, 2423, 4372],
#  [3297, 642, 5830, 1808, 2550, 8029, 1147, 7792, 3428],
#  [9215, 102, 1698, 7954, 6713],
#  [4142, 1665, 500, 6645, 5078, 963, 7070, 6676],
#  [1529,
#   3677,
#   6524,
#   1555,
#   8120,
#   9699,
#   2748,
#   2674,
#   4663,
#   6805,
#   3162,
#   7287,
#   4159,
#   4063,
#   6645,
#   9140,
#   3050],
#  [7864,
#   5857,
#   7072,
#   9112,
#   1630,
#   5271,
#   2317,
#   5323,
#   9005,
#   5271,
#   5620,
#   6645,
#   6883,
#   6821,
#   963,
#   5971,
#   8668,
#   5971,
#   5017,
#   5381,
#   5078,
#   963,
#   3540],
#  [6890, 6573, 2980, 6128, 6645, 6883, 2340, 963, 8283, 1011],
#  [2744, 8478, 7251, 9350, 8589, 6645, 9140, 6984, 698, 6645, 9140, 7060, 6031],
#  [2403, 2550, 2093, 5942, 579, 1298, 8527, 2255],
#  [4727,
#   7100,
#   2667,
#   4970,
#   2980,
#   2767,
#   6645,
#   8394,
#   5452,
#   3744,
#   6940,
#   5381,
#   5078,
#   963,
#   9178],
#  [2627, 9858, 7246, 4159, 8969],
#  [6558, 7162, 3651, 1436, 7383, 8673, 8433],
#  [625,
#   6515,
#   5085,
#   8934,
#   8687,
#   6262,
#   3514,
#   6363,
#   6262,
#   7383,
#   5940,
#   8934,
#   9201,
#   1023,
#   7708,
#   6495,
#   7437,
#   6645,
#   9140,
#   2610],
#  [4120,
#   8983,
#   5330,
#   5571,
#   8163,
#   1054,
#   958,
#   6645,
#   9140,
#   177,
#   9348,
#   6645,
#   9140,
#   2476,
#   3293],
#  [8332, 6645, 5078, 963, 5906, 6676],
#  [7830,
#   6740,
#   5484,
#   873,
#   5484,
#   498,
#   734,
#   9905,
#   6814,
#   2244,
#   4117,
#   5381,
#   5078,
#   963,
#   1387],
#  [6645,
#   542,
#   963,
#   5123,
#   1354,
#   28,
#   7939,
#   1011,
#   1116,
#   1354,
#   7939,
#   2550,
#   3759,
#   9550,
#   4204,
#   7403,
#   9021,
#   5078,
#   963,
#   2608],
#  [8679, 1352, 4912, 8969],
#  [2620, 7668, 7817, 6096, 3311, 348, 3166, 7668, 1501],
#  [2992, 6568, 2744, 1353, 6518, 4221, 759, 7159, 4555],
#  [1789, 7839, 666, 1137, 1875],
#  [9687,
#   5323,
#   9357,
#   4107,
#   2341,
#   3060,
#   8091,
#   5831,
#   5412,
#   9511,
#   8954,
#   5078,
#   963,
#   4592],
#  [3398, 8708, 5410, 3307, 1221, 6645, 9140, 646, 7338, 6645, 9140, 3486, 4625],
#  [9200, 9945, 5060, 7701, 2923],
#  [3087,
#   4160,
#   5499,
#   8486,
#   2111,
#   2489,
#   2619,
#   7792,
#   2619,
#   7792,
#   2619,
#   7792,
#   5381,
#   5078,
#   963,
#   8001],
#  [4555, 1523, 5323, 5484, 5557, 6645, 9140, 6818, 6645, 9140, 4158],
#  [5484,
#   7683,
#   3345,
#   5262,
#   6398,
#   7172,
#   5702,
#   9137,
#   6645,
#   9140,
#   8982,
#   1516,
#   6645,
#   9140,
#   9690,
#   3860],
#  [8021, 9627, 4106, 8840, 814, 4599, 6513],
#  [7558, 7900, 2093, 759, 2739, 445, 1640, 8399, 6645, 9140, 6939, 9752],
#  [8892, 6685, 7881, 1081, 9575, 9501, 6067, 8874, 8395, 2016, 5999, 4261],
#  [5779,
#   8077,
#   7172,
#   7667,
#   1901,
#   6753,
#   9385,
#   1845,
#   7403,
#   5831,
#   6645,
#   183,
#   8159,
#   5429],
#  [1390, 5331, 1646, 8507, 726, 3873, 2775, 6645, 5078, 963, 1390, 5331, 6676],
#  [428, 259, 2496],
#  [925, 9338, 8040, 3891, 2498, 989, 5361, 4722, 6645, 9140, 7515],
#  [8800,
#   4069,
#   21,
#   6314,
#   3752,
#   950,
#   2440,
#   1839,
#   7541,
#   7890,
#   581,
#   7688,
#   6040,
#   5078,
#   963,
#   8505,
#   5116,
#   8810],
#  [9728,
#   9451,
#   6465,
#   1546,
#   4922,
#   8171,
#   7701,
#   1771,
#   2648,
#   6645,
#   9140,
#   5359,
#   2064],
#  [7275, 252, 6645, 6513, 6555],
#  [1323,
#   9165,
#   5553,
#   5685,
#   3996,
#   4261,
#   6645,
#   9140,
#   2424,
#   2423,
#   552,
#   6645,
#   9140,
#   4493],
#  [6603, 2975],
#  [642, 2261, 9873, 5078, 963, 7671],
#  [528, 9410, 8634, 8395, 9575, 6645, 9140, 3198, 5802],
#  [6062, 2031, 9624, 9265, 6193, 4099, 8186],
#  [1564,
#   2041,
#   3132,
#   1374,
#   5387,
#   4912,
#   3603,
#   3593,
#   6645,
#   2845,
#   8159,
#   9398,
#   3916,
#   6774,
#   5078,
#   963,
#   2893],
#  [6906, 1256, 6417, 6065, 7461, 8618, 6263, 5367, 7159, 952, 9529],
#  [774, 437, 2654, 4776, 8917, 6645, 9140, 4175, 6730],
#  [7802, 7536, 4829, 9357, 5795, 541, 9705, 2131],
#  [3954, 108, 1535, 1221, 4388, 8421, 6645, 9140, 4209, 6645, 9140, 8738, 8755],
#  [43, 7613, 2078, 6645, 9140, 2165],
#  [2015, 4605, 8764, 422, 6113, 473, 5381, 5078, 963, 3492],
#  [2222, 2004, 1765, 6465, 8936, 1910],
#  [1846,
#   8792,
#   5400,
#   9156,
#   1132,
#   7203,
#   6491,
#   4555,
#   7166,
#   6645,
#   9140,
#   3899,
#   6645,
#   9140,
#   5480],
#  [6645, 9140, 4686, 7267, 8679],
#  [2373,
#   1766,
#   2977,
#   5546,
#   3623,
#   2486,
#   1083,
#   6645,
#   9140,
#   5257,
#   4673,
#   5795,
#   6645,
#   9140,
#   3014,
#   5882],
#  [6193, 7750, 7000, 1515, 6645, 5078, 963, 9013, 6676],
#  [2644,
#   7501,
#   795,
#   8037,
#   9057,
#   5290,
#   7357,
#   3921,
#   6645,
#   9140,
#   9184,
#   2901,
#   6645,
#   9140,
#   8854,
#   9104,
#   6492],
#  [6645, 5078, 963, 5919, 6676],
#  [6195, 5714, 6468, 7789, 665, 6916, 7588, 6645, 9140, 6940, 7254, 9601],
#  [9628, 8573, 2241, 5078, 963, 7095, 6676],
#  [9254,
#   50,
#   2366,
#   8843,
#   3431,
#   7720,
#   1766,
#   9094,
#   6645,
#   9140,
#   670,
#   6645,
#   9140,
#   6950,
#   8505,
#   4686],
#  [6764, 8674, 6627, 2550, 6577, 6303, 6645, 9998, 8283, 2510, 1221, 905, 2946],
#  [5924,
#   7166,
#   2550,
#   8507,
#   5400,
#   6645,
#   9140,
#   3474,
#   4207,
#   6645,
#   9140,
#   331,
#   3198,
#   2064],
#  [3602, 3170, 8274, 4856, 5659, 4893, 8021],
#  [6805,
#   8344,
#   2484,
#   459,
#   9718,
#   1950,
#   685,
#   8737,
#   4159,
#   6901,
#   9357,
#   2364,
#   6645,
#   9140,
#   4686,
#   2730,
#   6645,
#   9140,
#   9197,
#   2064,
#   1936],
#  [8936, 1444, 2454, 2586, 9986, 4027, 6645, 9140, 267, 9539, 4063],
#  [6495, 1323, 9357, 115, 7032, 9426, 9215, 9408, 9005, 5620],
#  [1286,
#   8395,
#   1311,
#   4361,
#   7214,
#   4414,
#   5141,
#   1119,
#   2841,
#   4506,
#   9243,
#   5078,
#   963,
#   5443,
#   4482],
#  [1939, 1689, 1715, 3265, 5801, 3297, 3912, 6645, 9140, 336, 8976, 827, 2624],
#  [7284,
#   1147,
#   2744,
#   5364,
#   7284,
#   9357,
#   6142,
#   894,
#   3308,
#   4159,
#   6902,
#   6645,
#   9140,
#   9751,
#   2220],
#  [7357, 5838, 5831, 2957, 8108, 5132, 5180, 6645, 9140, 5979],
#  [9392, 4969, 2488, 2931, 129, 6142, 6645, 9140, 7481, 1615, 6367],
#  [5387, 7708, 1845, 1643],
#  [5668, 5668, 9832, 6894, 6887, 3917, 3387, 5078, 963, 2912],
#  [721,
#   3748,
#   2364,
#   3122,
#   2364,
#   3340,
#   624,
#   2,
#   2850,
#   422,
#   6645,
#   6883,
#   8089,
#   963,
#   1522,
#   624,
#   7106,
#   1788,
#   5940,
#   4723,
#   298,
#   9184,
#   124,
#   5731,
#   6988,
#   9285,
#   6453,
#   6162,
#   5381,
#   5078,
#   963,
#   1078],
#  [5086, 1473, 3270, 1048, 6794, 3991, 1535, 3016],
#  [4836, 364, 8274, 6645, 5485, 5625, 8432],
#  [348, 261, 348, 2041, 7939, 8224, 9832, 9718, 9310, 8178, 9858, 6227, 7008],
#  [8665, 1258, 9447, 11, 721, 1352, 4185, 2040, 5381, 5078, 963, 2677],
#  [5404, 1209],
#  [1915, 9383, 7358, 7792, 5378, 8674, 2690, 4719],
#  [2402, 1309, 9528, 9335, 7118, 7567, 4504, 6645, 5078, 963, 8631, 6676],
#  [4221,
#   769,
#   4776,
#   6618,
#   814,
#   7952,
#   6579,
#   5323,
#   2417,
#   7436,
#   5620,
#   2230,
#   7343,
#   6684,
#   9899],
#  [1546, 6753, 4912, 4367],
#  [1845, 9945, 6080, 4699, 4993, 1646, 3575, 7487, 2009, 6645, 1686, 1964],
#  [],
#  [6350, 9970, 9123, 2744, 5089, 1147, 7881],
#  [6603, 3519, 6753, 8602],
#  [7903, 3770, 5162, 1884, 8277, 8216, 5078, 963, 3469, 2923],
#  [1631, 3136, 4725, 7821, 7821, 5381, 5078, 963, 6294, 4372],
#  [9851, 6868, 9970, 2089, 7731, 8899, 6541, 7792, 6128],
#  [5057, 5451, 8442, 3076, 1137, 6645, 9140, 8505, 8407],
#  [8333, 1910],
#  [8195,
#   5671,
#   7711,
#   5676,
#   3646,
#   1653,
#   6645,
#   3126,
#   963,
#   6645,
#   3911,
#   4160,
#   963,
#   9184,
#   8668,
#   5443,
#   6645,
#   6940,
#   5556,
#   8159,
#   8348,
#   2186,
#   1701,
#   657,
#   3198,
#   3492,
#   8055,
#   6739,
#   6988,
#   3069,
#   5635,
#   6476,
#   467,
#   2652,
#   1900,
#   4791,
#   3062,
#   2978,
#   1923,
#   2936,
#   2220,
#   8531,
#   6,
#   3116,
#   8708,
#   8111,
#   7722,
#   8283,
#   5349],
#  [9385, 2262, 642, 8433, 5381, 5078, 963, 6310],
#  [3001, 5078, 963, 728, 9457],
#  [721,
#   1151,
#   811,
#   7791,
#   1151,
#   1327,
#   6857,
#   7238,
#   6645,
#   6883,
#   2340,
#   963,
#   8283,
#   9318],
#  [808, 1339, 9980, 5295, 5831, 5443, 5668],
#  [5724, 4630],
#  [4618,
#   164,
#   6645,
#   6883,
#   4160,
#   963,
#   7345,
#   7567,
#   164,
#   9282,
#   5092,
#   24,
#   8804,
#   5940,
#   1589,
#   8674,
#   8778],
#  [5518, 7178, 9140, 5078, 963, 4900],
#  [6538,
#   2220,
#   8551,
#   2945,
#   8341,
#   3109,
#   5125,
#   8999,
#   8744,
#   4050,
#   5381,
#   5078,
#   963,
#   703,
#   3046,
#   9049],
#  [9153,
#   4629,
#   4018,
#   43,
#   4869,
#   1309,
#   9759,
#   1746,
#   8243,
#   993,
#   6588,
#   1961,
#   6847,
#   9899,
#   8395],
#  [1845, 9392, 6726, 2829, 4003, 7103, 6138, 1486, 6645, 9140, 7023],
#  [5668,
#   9832,
#   8995,
#   6894,
#   4110,
#   6645,
#   2108,
#   9851,
#   963,
#   6480,
#   4455,
#   981,
#   5078,
#   963,
#   3266,
#   113],
#  [4922, 7864, 4683],
#  [3506,
#   7357,
#   9765,
#   918,
#   9447,
#   8937,
#   6645,
#   9140,
#   1202,
#   1923,
#   3198,
#   3777,
#   6788,
#   6645,
#   9140,
#   5940,
#   9936],
#  [1562,
#   3254,
#   8171,
#   3035,
#   4178,
#   5680,
#   6665,
#   7792,
#   7383,
#   9348,
#   7677,
#   3410,
#   6645,
#   1937,
#   8345],
#  [9268,
#   3205,
#   2739,
#   8867,
#   3297,
#   5923,
#   7588,
#   7026,
#   9989,
#   6645,
#   9140,
#   4874,
#   9169,
#   6645,
#   9140,
#   3198,
#   4567,
#   648],
#  [6340, 6262, 5984, 6847, 6685, 5836, 747, 2, 70, 3194, 7859],
#  [2137, 7032, 9068, 4859, 8552, 6645, 9140, 4372, 9397, 6286],
#  [6639, 6128, 9200, 6096, 2883],
#  [4159, 8766, 4912, 2424, 4654, 2467, 4159, 6732, 482, 8195],
#  [6493,
#   1868,
#   7407,
#   4611,
#   1915,
#   7562,
#   1961,
#   1019,
#   6902,
#   258,
#   5583,
#   3162,
#   6502,
#   6645,
#   9140,
#   1901,
#   5940,
#   9184],
#  [2081, 772, 1390, 725, 2663, 8857],
#  [3499,
#   9891,
#   4738,
#   9891,
#   6793,
#   6645,
#   8207,
#   2946,
#   963,
#   3499,
#   9891,
#   4738,
#   9891,
#   6793,
#   8875,
#   4068],
#  [3089,
#   6208,
#   8205,
#   6645,
#   5485,
#   5625,
#   1337,
#   8283,
#   9184,
#   5381,
#   5078,
#   963,
#   8283,
#   1701,
#   5840],
#  [4436,
#   498,
#   7498,
#   5942,
#   6459,
#   2041,
#   3633,
#   3250,
#   6901,
#   6645,
#   9140,
#   8959,
#   6645,
#   9140,
#   5989],
#  [3931, 2111, 8077, 9177, 6645, 9140, 6770, 8934, 5044],
#  [5443, 8274, 5892, 7923, 2633, 914, 9400, 3799, 7332, 9005, 5620],
#  [1317, 215, 2093, 8120, 108],
#  [3534, 6149, 351, 3435, 2016, 2093, 8013, 9681, 3170, 5367, 4381, 7000, 4459],
#  [6567, 3398, 449, 9426, 1170, 3837, 8776, 6680, 9610, 5620],
#  [2447, 7881, 4899, 2012, 8073, 5547, 8681, 6621, 2447, 8250, 8250, 8433],
#  [8358, 7777, 7275, 2760, 4922, 774, 9930, 5690, 5078, 963, 9607, 2087, 5731],
#  [6128, 1856, 1186, 5387, 1826, 642, 6227, 3726],
#  [9447, 8615, 3049, 9959, 1546, 2349, 4513, 1309],
#  [1147, 814, 9432, 2041, 1666, 3016],
#  [1475, 4110, 4431, 5230, 8118, 5125, 3871, 4431, 3899, 443, 6212, 1643, 7446],
#  [474, 5441, 1506, 4970, 3859, 1349, 4499, 7917, 688, 9242, 3864, 8317],
#  [7343,
#   6911,
#   772,
#   3329,
#   1788,
#   7007,
#   7730,
#   4526,
#   209,
#   5942,
#   6487,
#   6665,
#   721,
#   6645,
#   9140,
#   8994,
#   2423,
#   6645,
#   9140,
#   5731,
#   7283,
#   2169],
#  [7770,
#   8587,
#   323,
#   5400,
#   4286,
#   6461,
#   2966,
#   1514,
#   6645,
#   298,
#   8032,
#   8283,
#   5381,
#   5078,
#   963,
#   8803,
#   8394,
#   5731],
#  [3434,
#   9468,
#   5571,
#   4722,
#   7895,
#   1352,
#   2039,
#   5066,
#   6645,
#   9140,
#   4137,
#   6940,
#   6770,
#   3434,
#   6645,
#   9140,
#   4876,
#   3957],
#  [2604, 2093, 2782, 6226, 5942, 3143, 3138],
#  [8133, 1846, 5139, 9718, 474],
#  [8433, 695, 1826, 6398, 2460, 5716, 8077, 157, 8870, 5716, 6398],
#  [6225, 3102],
#  [1147, 8012, 4922, 1884, 8904, 5631, 4707, 8407, 9451, 625, 2447],
#  [318,
#   7655,
#   15,
#   442,
#   4159,
#   4110,
#   1147,
#   6753,
#   7200,
#   75,
#   3950,
#   6645,
#   9140,
#   6343,
#   1701,
#   8182,
#   4063,
#   2423,
#   6645,
#   9140,
#   29,
#   7267],
#  [5450, 3301, 9378, 9038, 1113, 1537, 3811, 94],
#  [2765,
#   4615,
#   5134,
#   7731,
#   8064,
#   1629,
#   6645,
#   6883,
#   4160,
#   963,
#   3108,
#   7315,
#   8316,
#   357,
#   8064,
#   2660],
#  [6887, 5904, 3973, 5243, 2653, 6645, 9140, 9491, 3732, 8279, 3046],
#  [3350, 8772, 5381, 5078, 963, 6133, 3649],
#  [6522, 7951, 8890, 2220, 3181, 371, 6861],
#  [1546, 6567, 2093, 2818, 4596, 1329],
#  [9948,
#   4159,
#   4108,
#   7786,
#   4620,
#   4841,
#   8118,
#   4689,
#   8197,
#   6645,
#   9140,
#   6289,
#   9596,
#   432],
#  [4555,
#   958,
#   5323,
#   2074,
#   443,
#   3075,
#   7772,
#   6645,
#   9140,
#   4372,
#   4064,
#   6645,
#   9140,
#   9245,
#   6316,
#   6645,
#   9140,
#   2423,
#   1482],
#  [8665, 5851, 9791, 8395, 3985, 6128, 6117],
#  [664, 3266, 5690, 9402, 5952, 6794, 3569, 6143, 6645, 9140, 905, 8386],
#  [9768, 9310, 3064, 492],
#  [6493,
#   7746,
#   8138,
#   8445,
#   6397,
#   1147,
#   8789,
#   4159,
#   9055,
#   7200,
#   15,
#   4605,
#   2158,
#   6524,
#   6645,
#   9140,
#   8836],
#  [3990, 6142],
#  [1019, 5612, 5442, 769, 9003, 4286, 2743, 2093, 2093],
#  [6041, 8195, 5620, 7000],
#  [6567,
#   3398,
#   8843,
#   551,
#   5234,
#   3185,
#   3427,
#   3297,
#   4083,
#   4601,
#   6645,
#   9140,
#   5573,
#   5636,
#   6289],
#  [1846, 3873, 6822, 7048, 870, 4159, 6031, 843, 6645, 9140, 3326, 2717],
#  [4108, 9336, 9034, 586, 9232, 7881, 8895, 3138],
#  [6557, 539, 6300, 4172, 1912, 4912, 4620, 7383],
#  [8970,
#   7338,
#   2422,
#   6577,
#   9038,
#   1035,
#   9533,
#   4594,
#   4592,
#   8792,
#   6095,
#   7338,
#   4374,
#   1737,
#   2159,
#   4608,
#   1638,
#   551,
#   5311,
#   6645,
#   9140,
#   5920,
#   5940],
#  [8870, 7843, 985, 7022, 5381, 5078, 963, 9184, 5761, 526],
#  [4295,
#   104,
#   3195,
#   3985,
#   6314,
#   642,
#   5041,
#   9149,
#   6645,
#   9942,
#   2556,
#   59,
#   322,
#   5381,
#   5078,
#   963,
#   679,
#   8072],
#  [1846,
#   5422,
#   2434,
#   7561,
#   3365,
#   2662,
#   3166,
#   505,
#   6577,
#   1646,
#   2095,
#   251,
#   348,
#   1966,
#   6327],
#  [617, 6645, 5078, 963, 1598, 6676],
#  [9851, 5680, 9718, 1952, 6243, 6645, 8082, 9140, 4063, 4686, 5364, 4723],
#  [6573,
#   7045,
#   5321,
#   4175,
#   6645,
#   9140,
#   240,
#   8254,
#   2694,
#   8914,
#   9995,
#   229,
#   5373,
#   6857,
#   6645,
#   9140,
#   2749,
#   2064],
#  [7881, 5372, 2041, 5105, 9951, 4175, 6645, 9140, 7296],
#  [6404, 6645, 9140, 5634, 6566],
#  [7172, 7666, 8604, 2289, 8508, 6645, 9140, 5962, 8198],
#  [9002, 6249],
#  [2257, 3519, 5851, 4126, 2257, 5392, 1912, 8870, 7561, 5381, 5078, 963, 1330],
#  [4159, 9057, 9724, 7131, 1845, 3298, 7574, 8665, 1240, 789],
#  [4286,
#   6142,
#   3205,
#   5633,
#   4286,
#   1348,
#   8870,
#   3574,
#   4917,
#   2743,
#   4083,
#   4601,
#   6645,
#   9140,
#   8530,
#   1611],
#  [9447, 5992, 9169, 9447, 9169],
#  [642, 8615, 4050, 6566],
#  [6493,
#   7455,
#   6493,
#   8436,
#   4159,
#   7036,
#   9767,
#   4912,
#   6826,
#   584,
#   7957,
#   3362,
#   8207,
#   6645,
#   9140,
#   1093],
#  [2744, 4634, 3491, 205, 5097, 2074, 7162, 8250, 6885],
#  [6522, 2813, 8222, 9995, 3314, 7401, 2843],
#  [9410,
#   7862,
#   6645,
#   3912,
#   2895,
#   963,
#   4063,
#   9369,
#   6940,
#   6289,
#   5940,
#   6940,
#   3497,
#   5940,
#   6940],
#  [1845, 2016, 6757, 4605],
#  [7383, 1367, 442, 2746, 7403, 5211, 6080, 3863, 5078, 963, 8508, 6676],
#  [6645, 9140, 6535, 5731],
#  [2081,
#   4189,
#   1643,
#   6749,
#   8209,
#   894,
#   1448,
#   5347,
#   2230,
#   894,
#   6645,
#   1755,
#   963,
#   5005,
#   894,
#   5381,
#   5078,
#   963,
#   469,
#   6963],
#  [8251, 4335, 6844, 1546, 4016, 6645, 4370, 2102, 8283, 2472, 4063],
#  [2433,
#   3655,
#   3874,
#   3105,
#   9791,
#   6645,
#   6883,
#   5404,
#   963,
#   9005,
#   5643,
#   5999,
#   8409,
#   5052,
#   1529,
#   3718,
#   8013,
#   9720,
#   748,
#   2633,
#   6243,
#   9337,
#   4610,
#   5381,
#   5078,
#   963,
#   5830,
#   4063],
#  ...]

# %%
#We pad each 
sent_length=20
docs = pad_sequences(onehot_rep, padding='pre', maxlen=sent_length)

# %%
docs
# Out:
# array([[   0,    0,    0, ...,  963, 1174, 4641],
#        [   0,    0,    0, ..., 4474, 5034, 7908],
#        [   0,    0,    0, ..., 6645,  330, 3323],
#        ...,
#        [   0,    0,    0, ..., 9140, 7656, 6289],
#        [   0, 3484, 5942, ..., 3943, 9811,  940],
#        [   0,    0,    0, ..., 6256, 4663,  997]], dtype=int32)

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
xyz = []
for i in range(0, len(X_test)):
    te = re.sub('[^a-zA-Z]', ' ', X_test['Tweet'][i])
    te = te.lower()
    te = te.split()
    
    te = [ps.stem(word) for word in te if not word in stopwords.words('english')]
    te = ' '.join(te)
    xyz.append(te)

# %%
onehot_rep_test = [one_hot(words, voc_size) for words in xyz]

# %%
test_docs = pad_sequences(onehot_rep_test, padding='pre', maxlen=sent_length)

# %%
test_docs.shape
# Out:
# (630, 20)

# %%
docs.shape
# Out:
# (11968, 20)

# %%
docs.shape
# Out:
# (11968, 20)

# %%
import numpy as np

# %%
X_tr_final = np.array(docs)
y_tr_final = np.array(y_tr)

# %%
X_tr_final
# Out:
# array([[   0,    0,    0, ...,  963, 1174, 4641],
#        [   0,    0,    0, ..., 4474, 5034, 7908],
#        [   0,    0,    0, ..., 6645,  330, 3323],
#        ...,
#        [   0,    0,    0, ..., 9140, 7656, 6289],
#        [   0, 3484, 5942, ..., 3943, 9811,  940],
#        [   0,    0,    0, ..., 6256, 4663,  997]], dtype=int32)
